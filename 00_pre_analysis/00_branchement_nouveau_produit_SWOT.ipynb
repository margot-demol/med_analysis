# %%
import numpy as np
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt

import os
from glob import glob

# %%
v102 = "/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_1.0.2"
v201 = "/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1"

# %%
f1 = sorted(glob(os.path.join(v102, "*.zarr")))
f2 = sorted(glob(os.path.join(v201, "*.zarr")))

# %%
f2
# Out:
# ['/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_474.zarr',
#  '/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_476.zarr',
#  '/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_478.zarr',
#  '/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_479.zarr',
#  '/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_481.zarr',
#  '/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_482.zarr',
#  '/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_483.zarr',
#  '/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_484.zarr',
#  '/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_485.zarr',
#  '/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_486.zarr',
#  '/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_487.zarr',
#  '/home/datawork-lops-oc/aponte/swot/cswot/swot/L3_calval_2.0.1/16_488.zarr',
# ...

# %%
pass_cycle = "16_478"
ds1 = xr.open_dataset(os.path.join(v102, pass_cycle + ".zarr"))
ds2 = xr.open_dataset(os.path.join(v201, pass_cycle + ".zarr"))
# Out:
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)

# %%
ds1.time
# Out:
# <xarray.DataArray 'time' (num_lines: 481)> Size: 4kB
# array(['2023-04-02T10:23:53.195702272', '2023-04-02T10:23:53.506079616',
#        '2023-04-02T10:23:53.816469120', ..., '2023-04-02T10:26:21.526023040',
#        '2023-04-02T10:26:21.836351616', '2023-04-02T10:26:22.146495360'],
#       dtype='datetime64[ns]')
# Coordinates:
#     latitude_nadir   (num_lines) float64 4kB ...
#     longitude_nadir  (num_lines) float64 4kB ...
#     time             (num_lines) datetime64[ns] 4kB 2023-04-02T10:23:53.19570...
# Dimensions without coordinates: num_lines
# Attributes:
#     comment:             Time of measurement in seconds in the UTC time scale...
#     leap_second:         0000-00-00T00:00:00Z
#     long_name:           time in UTC
#     standard_name:       time
#     tai_utc_difference:  37.0

# %%
ds2["time"] = (ds2.time - np.timedelta64(946684800000000000, "ns")).compute()
# Out:
# <xarray.DataArray 'time' (num_lines: 481)> Size: 4kB
# array(['2023-04-02T10:23:53.195702272', '2023-04-02T10:23:53.506079616',
#        '2023-04-02T10:23:53.816469120', '2023-04-02T10:23:54.126881280',
#        '2023-04-02T10:23:54.437253760', '2023-04-02T10:23:54.747693312',
#        '2023-04-02T10:23:55.057948288', '2023-04-02T10:23:55.368721024',
#        '2023-04-02T10:23:55.679886080', '2023-04-02T10:23:55.990302720',
#        '2023-04-02T10:23:56.300655232', '2023-04-02T10:23:56.611081344',
#        '2023-04-02T10:23:56.921447040', '2023-04-02T10:23:57.231818624',
#        '2023-04-02T10:23:57.542245120', '2023-04-02T10:23:57.852662272',
#        '2023-04-02T10:23:58.163030784', '2023-04-02T10:23:58.473427840',
#        '2023-04-02T10:23:58.783700480', '2023-04-02T10:23:59.094212096',
#        '2023-04-02T10:23:59.404891904', '2023-04-02T10:23:59.715182336',
#        '2023-04-02T10:24:00.025480192', '2023-04-02T10:24:00.335814016',
# ...

# %%
np.timedelta64(30, "Y").astype("<m8[ns]")
# Out:
# numpy.timedelta64(946708560000000000,'ns')
