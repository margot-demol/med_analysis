# %% [markdown]
# ____
# # Temporal dependency

# %%
import numpy as np
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt

import os
from glob import glob

from cstes import swot_dir, drifters_dir, get_proj, lonlat2xy, zarr_dir, surface_drifters, depth_drifters, depth_100, depth_50, images_dir, U2, err_acc
from diagnosis import update_dict, dataset_coloc_combs, dataset_coloc_combs, prepared_drifters, prepared_wd, prepared_alti, compute_variance, compute_variance_groupby, plot_error

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.geodesic as cgeo
crs = ccrs.PlateCarree()

import cartopy.geodesic as geod
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import pyproj
from pyproj import Geod

from rasterio.transform import Affine

import pynsitu as pyn

from diagnosis import synthetic_figure
from cstes import U2, c0
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Warning: could not import gsw
# Warning: could not import pytide
# Warning: could not import utide
# Warning: could not import pyTMD

# %% [markdown]
# _______
# # Data

# %%
distance_to_coast_max = 20e3
alti_product_key='swot2km'
drifter_preprocess = ''
drifter_preprocess_param=''
from diagnosis import define_coloc_source
colocs_sources = define_coloc_source('10d', drifter_preprocess, drifter_preprocess_param)

# %% [markdown]
# _______
# # Generate

# %%
APK = ['swot2km', 'L4_noswot_regional_swottime','L4_noswot_global_swottime','L4_withnadirswot_swottime']

# SURFACE
base_dic = dict(dt='10d', 
        drifter_preprocess = drifter_preprocess,
        drifter_preprocess_param=drifter_preprocess_param,
        alti_product_key=alti_product_key,
        alti_diff_method = 'fromduacsv',
        alti_diff_method_param = '',
        ggd_var = 'fromduacsv',
        wd_product_key = 'era5', 
        wd_model ='rio', 
        wd_depth = '0')

comb_list = [update_dict(base_dic, {'alti_product_key':apk}) for apk in APK]

ds0 = dataset_coloc_combs(comb_list, nearest =False, remove_id_outliers = True)
ds0['comb'] = ds0['id_comb']
ds0['id_comb'] = ('id_comb',APK)
distance_to_coast = ds0.distance_to_coast.isel(id_comb = 0)
ds0['distance_to_coast'] = ('row_number', distance_to_coast.values)

#DEPTH 15M
base_dic = update_dict(base_dic, dict(wd_depth = '15'))
comb_list = [update_dict(base_dic, {'alti_product_key':apk}) for apk in APK]

ds15 = dataset_coloc_combs(comb_list, nearest =False, remove_id_outliers = True)
ds15['comb'] = ds15['id_comb']
ds15['id_comb'] = ('id_comb',APK)
distance_to_coast = ds15.distance_to_coast.isel(id_comb = 0)
ds15['distance_to_coast'] = ('row_number', distance_to_coast.values)

DS = xr.concat([ds0.where(ds0.depth==0, drop=True), ds15.where(ds15.depth==15, drop=True)], dim='row_number')
#DS = DS.where(DS.time_to_swot/pd.Timedelta('1h')<dt).dropna('row_number')
#DS = DS.where((abs(DS.ggde)<max_ggd) & (abs(DS.ggdn)<max_ggd), drop=True)
DSG = DS.where(DS.distance_to_coast>distance_to_coast_max, drop=True)

# Closure figs
dsg = compute_variance(DSG, compute_error='centrallimit')/U2
# Out:
# 6371649
# 10d_spectral_decomp_all_med_variational_10min_v1____swot2km_fromduacsv__fromduacsv__era5_rio0
# only 'fromduacsv' method is available for L4
# 7300465
# 10d_spectral_decomp_all_med_variational_10min_v1____L4_noswot_regional_swottime_fromduacsv__fromduacsv__era5_rio0
# only 'fromduacsv' method is available for L4
# 7365071
# 10d_spectral_decomp_all_med_variational_10min_v1____L4_noswot_global_swottime_fromduacsv__fromduacsv__era5_rio0
# only 'fromduacsv' method is available for L4
# 7448586
# 10d_spectral_decomp_all_med_variational_10min_v1____L4_withnadirswot_swottime_fromduacsv__fromduacsv__era5_rio0
# Identified SWOT and drifter outliers have been removed
# 6371649
# 10d_spectral_decomp_all_med_variational_10min_v1____swot2km_fromduacsv__fromduacsv__era5_rio15
# only 'fromduacsv' method is available for L4
# 7300465
# 10d_spectral_decomp_all_med_variational_10min_v1____L4_noswot_regional_swottime_fromduacsv__fromduacsv__era5_rio15
# only 'fromduacsv' method is available for L4
# 7365071
# 10d_spectral_decomp_all_med_variational_10min_v1____L4_noswot_global_swottime_fromduacsv__fromduacsv__era5_rio15
# only 'fromduacsv' method is available for L4
# 7448586
# 10d_spectral_decomp_all_med_variational_10min_v1____L4_withnadirswot_swottime_fromduacsv__fromduacsv__era5_rio15
# Identified SWOT and drifter outliers have been removed

# %%
# Closure figs
dsg = compute_variance(DSG, compute_error='centrallimit')/U2
# Out:
# KeyboardInterrupt

# %%
DS.to_zarr(f'/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/diag_files/{colocs_sources}_swottime.zarr')

# %%
DS
# Out:
# <xarray.Dataset> Size: 9GB
# Dimensions:            (id_comb: 4, row_number: 7021501)
# Coordinates: (12/13)
#     cycle_number       (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     datetime           (id_comb, row_number) datetime64[ns] 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     depth              (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     distance_to_coast  (row_number) float64 56MB dask.array<chunksize=(109711,), meta=np.ndarray>
#     drifter_id         (id_comb, row_number) object 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     drifter_type       (id_comb, row_number) object 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     ...                 ...
#     latitude           (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     longitude          (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     pass_number        (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     phi                (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#   * row_number         (row_number) int64 56MB 323 324 325 ... 7490158 7490159
#     time_to_swot       (id_comb, row_number) timedelta64[ns] 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
# Data variables: (12/31)
#     acce               (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     accn               (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     comb               (id_comb, row_number) object 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     core               (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     corn               (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     exce_acc           (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     ...                 ...
#     prodn_cor_wd       (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     prodn_ggd_wd       (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     sume               (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     sumn               (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     wde                (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>
#     wdn                (id_comb, row_number) float64 225MB dask.array<chunksize=(1, 219422), meta=np.ndarray>

# %% [markdown]
# # If already generated

# %%
DS = xr.open_zarr(f'/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/diag_files/{colocs_sources}_swottime.zarr').persist()
# Out:
# KeyboardInterrupt

# %%
DSG = DS.where(DS.distance_to_coast.compute()>distance_to_coast_max, drop=True)

# %%
DSG
# Out:
# <xarray.Dataset> Size: 8GB
# Dimensions:            (id_comb: 4, row_number: 5816513)
# Coordinates: (12/13)
#     cycle_number       (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     datetime           (id_comb, row_number) datetime64[ns] 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     depth              (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     distance_to_coast  (row_number) float64 47MB 1.1e+05 1.1e+05 ... 3.296e+04
#     drifter_id         (id_comb, row_number) object 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     drifter_type       (id_comb, row_number) object 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     ...                 ...
#     latitude           (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     longitude          (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     pass_number        (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     phi                (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#   * row_number         (row_number) int64 47MB 323 324 325 ... 7490071 7490072
#     time_to_swot       (id_comb, row_number) timedelta64[ns] 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
# Data variables: (12/31)
#     acce               (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     accn               (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     comb               (id_comb, row_number) object 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     core               (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     corn               (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     exce_acc           (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     ...                 ...
#     prodn_cor_wd       (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     prodn_ggd_wd       (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     sume               (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     sumn               (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     wde                (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>
#     wdn                (id_comb, row_number) float64 186MB dask.array<chunksize=(1, 181992), meta=np.ndarray>

# %% [markdown]
# # Temporal binned

# %%
dth = 36 #bin in hours

# %%
DSG['time_bin'] = (DSG.time_to_swot/pd.Timedelta('1h')//dth)*dth/24
list_h = np.unique(DSG.time_bin)

D = []
for c in DSG.id_comb :
    dff = DSG.sel(id_comb=c).to_dataframe().reset_index().set_index('row_number')
    D.append(compute_variance_groupby(dff, groupby = 'time_bin', compute_error = 'centrallimit'))
    print(c)
dsg = xr.concat(D, dim='id_comb')
dsg['id_comb'] = DSG.id_comb
dsg.to_netcdf(os.path.join(zarr_dir, 'diag_files', f'{dth}hbin_mean_{colocs_sources}_swottime.nc'))
dsg['time_bin'] = (dsg.time_bin+dth/2/24).assign_attrs({'long_name':r'Temporal mismatch $\Delta T$', 'units':'day'})
# Out:
# time_bin
# 0.0    882014
# 1.5    873396
# 3.0    871766
# 4.5    874468
# 6.0    875522
# 7.5    866852
# 9.0    572495
# Name: acce, dtype: int64
# time_bin
# 0.0    806
# 1.5    822
# 3.0    761
# 4.5    648
# 6.0    597
# 7.5    842
# 9.0    417
# dtype: int64
# <xarray.DataArray 'id_comb' ()> Size: 108B
# array('swot2km', dtype='<U27')
# Coordinates:
#     id_comb  <U27 108B 'swot2km'
# time_bin
# 0.0    882011
# 1.5    873394
# 3.0    871765
# 4.5    874465
# 6.0    875519
# 7.5    866849
# 9.0    572493
# Name: acce, dtype: int64
# time_bin
# 0.0    806
# 1.5    822
# 3.0    761
# 4.5    648
# 6.0    597
# 7.5    842
# 9.0    417
# dtype: int64
# <xarray.DataArray 'id_comb' ()> Size: 108B
# array('L4_noswot_regional_swottime', dtype='<U27')
# Coordinates:
#     id_comb  <U27 108B 'L4_noswot_regional_swottime'
# time_bin
# 0.0    880823
# 1.5    872142
# 3.0    870473
# 4.5    873320
# 6.0    874311
# 7.5    865744
# 9.0    571777
# Name: acce, dtype: int64
# time_bin
# 0.0    805
# 1.5    821
# 3.0    762
# 4.5    645
# 6.0    596
# 7.5    842
# 9.0    417
# dtype: int64
# <xarray.DataArray 'id_comb' ()> Size: 108B
# array('L4_noswot_global_swottime', dtype='<U27')
# Coordinates:
#     id_comb  <U27 108B 'L4_noswot_global_swottime'
# time_bin
# 0.0    882014
# 1.5    873396
# 3.0    871766
# 4.5    874468
# 6.0    875522
# 7.5    866852
# 9.0    572495
# Name: acce, dtype: int64
# time_bin
# 0.0    806
# 1.5    822
# 3.0    761
# 4.5    648
# 6.0    597
# 7.5    842
# 9.0    417
# dtype: int64
# <xarray.DataArray 'id_comb' ()> Size: 108B
# array('L4_withnadirswot_swottime', dtype='<U27')
# Coordinates:
#     id_comb  <U27 108B 'L4_withnadirswot_swottime'

# %%
dsg12=dsg

# %%
#dsg.to_netcdf(os.path.join(zarr_dir, 'diag_files', f'{dth}hbin_mean_{colocs_sources}.nc'))
dsg12['time_bin'] = (dsg12.time_bin).assign_attrs({'long_name':r'Temporal mismatch $\Delta T$', 'units':'day'})

# %%
dsg1 = xr.open_dataset(os.path.join(zarr_dir, 'diag_files', f'1hbin_mean_{colocs_sources}.nc'))
dsg12 = xr.open_dataset(os.path.join(zarr_dir, 'diag_files', f'12hbin_mean_{colocs_sources}.nc
# Out:
#   Cell In[26], line 2
#     dsg12 = xr.open_dataset(os.path.join(zarr_dir, 'diag_files', f'12hbin_mean_{colocs_sources}.nc
#                                                                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
dsg12['time_bin'] = dsg12.time_bin+1/4

# %%
dsg12['id_comb'] = ['L3-2km', 'L4-regional at SWOT time', 'L4-global at SWOT time', 'L4-SWOT-nadir at SWOT time']

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,4), frameon=False)
for c in dsg.sel(id_comb = ['L3-2km','L4-SWOT-nadir at SWOT time' ]).id_comb:
    #dsg1.sel(id_comb=c).B_ggd.plot(ax=ax, label = c.values)
    dsg12.sel(id_comb=c).B_ggd.plot(ax=ax, label = c.values)
    #plot_error(dsg1.sel(id_comb=c),'time_bin', 'B_ggd', ax, suf = 'er__')
    plot_error(dsg12.sel(id_comb=c),'time_bin', 'B_ggd', ax, suf = 'er__', alpha=0.5)
ax.axhline(0.97, ls ='--', color='orange', label = 'L4-SWOT-nadir')
ax.set_ylabel(r'Pressure gradient balanced contribution [$\gamma^2$]')
ax.grid()
ax.legend()
ax.set_title('')
# Out:
# Text(0.5, 1.0, '')

# %%
dsg12.nb_coloc.plot()
