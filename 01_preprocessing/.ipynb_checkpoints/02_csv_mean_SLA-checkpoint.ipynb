# %% [markdown]
# # Create file with $\langle SLA \rangle_t$

# %%
import numpy as np
import pandas as pd
import xarray as xr
import dask.array as da

import matplotlib.pyplot as plt

import os
from glob import glob
from swot import browse_swot_250m, browse_swot_2km, add_grid_metrics,rotate_ggd
from cstes import swot_dir_2km, zarr_dir

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.geodesic as cgeo
crs = ccrs.PlateCarree()

import cartopy.geodesic as geod
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# ______________
# # Functions

# %%
dfs = browse_swot_2km().reset_index()
df3 = dfs[dfs.pass_number==3]
df16 = dfs[dfs.pass_number==16]
# Out:
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask/config.py:742: FutureWarning: Dask configuration key 'distributed.scheduler.transition-log-length' has been deprecated; please use 'distributed.admin.low-level-log-length' instead
#   warnings.warn(
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask/config.py:742: FutureWarning: Dask configuration key 'distributed.comm.recent-messages-log-length' has been deprecated; please use 'distributed.admin.low-level-log-length' instead
#   warnings.warn(

# %%
ds3 = xr.open_mfdataset(df3.file.values, preprocess=prepared_concat)
# Out:
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# ...

# %%
ds3.pass_number.mean().compute()
# Out:
# <xarray.DataArray 'pass_number' ()> Size: 8B
# array(3.)

# %%
def prepared_concat(ds):
    cn = ds.cycle_number.mean().values
    ds =ds.drop_vars('cycle_number')
    ds['cycle_number']=('cycle_number', [cn])
    return ds
ds = xr.open_mfdataset(df.file.values, preprocess=prepared_concat)

# %%
ds3 = xr.open_mfdataset(df3.file.values, preprocess=prepared_concat)[['duacs_ssha_karin_2_filtered', 'duacs_ssha_karin_2_calibrated']]
ds16 = xr.open_mfdataset(df16.file.values, preprocess=prepared_concat)[['duacs_ssha_karin_2_filtered', 'duacs_ssha_karin_2_calibrated']]
# Out:
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# ...

# %%
ds3m.to_netcdf(os.path.join(zarr_dir, 'before_coloc','preprocessed_swot','swot2km', f'pass3_swot2km_meansla.nc'))
ds16m.to_netcdf(os.path.join(zarr_dir, 'before_coloc','preprocessed_swot','swot2km', f'pass16_swot2km_meansla.nc'))

# %%
# Out:
# <xarray.Dataset> Size: 50MB
# Dimensions:                        (cycle_number: 91, num_lines: 481,
#                                     num_pixels: 69)
# Coordinates:
#     latitude                       (num_lines, num_pixels) float64 266kB dask.array<chunksize=(481, 69), meta=np.ndarray>
#     latitude_nadir                 (cycle_number, num_lines) float64 350kB dask.array<chunksize=(1, 481), meta=np.ndarray>
#     longitude                      (num_lines, num_pixels) float64 266kB dask.array<chunksize=(481, 69), meta=np.ndarray>
#     longitude_nadir                (cycle_number, num_lines) float64 350kB dask.array<chunksize=(1, 481), meta=np.ndarray>
#     time                           (cycle_number, num_lines) datetime64[ns] 350kB dask.array<chunksize=(1, 481), meta=np.ndarray>
#   * cycle_number                   (cycle_number) float64 728B 478.0 ... 577.0
# Dimensions without coordinates: num_lines, num_pixels
# Data variables:
# ...

# %%
ds3m = ds3.rename({'duacs_ssha_karin_2_filtered':'mean_slaf','duacs_ssha_karin_2_calibrated':'mean_slac' }).mean('cycle_number').compute()
ds16m = ds16.rename({'duacs_ssha_karin_2_filtered':'mean_slaf','duacs_ssha_karin_2_calibrated':'mean_slac' }).mean('cycle_number').compute()

# %%
for ds in [ds3m, ds16m]:
    ds['mean_slaf'] = ds['mean_slaf'].assign_attrs({'long_name' :'Mean filtered SLA over the Fast sampling period', 'units':'m'})
    ds['mean_slac'] = ds['mean_slac'].assign_attrs({'long_name' :'Mean calibrated SLA over the Fast sampling period', 'units':'m'})


bbox = [0.7, 6.1, 36.6, 43.4]

fig = plt.figure(figsize=(20,10), frameon =False)
vmin, vmax = -0.1, 0.1

ax = fig.add_subplot(1,2,1, projection=ccrs.Orthographic(4,40))
ds3m.mean_slaf.plot(x='longitude', y='latitude',ax=ax, transform=crs, vmin=vmin, vmax=vmax)
ds16m.mean_slaf.plot(x='longitude', y='latitude',ax=ax, transform=crs, add_colorbar=False, vmin=vmin, vmax=vmax)
ax.set_title(f'Mean filtered SLA over the Fast sampling period')
gl = ax.gridlines(draw_labels=True,)
ax.set_extent(bbox)
gl.top_labels = False
gl.right_labels = False


ax = fig.add_subplot(1,2,2, projection=ccrs.Orthographic(4,40))
ds3m.mean_slac.plot(x='longitude', y='latitude',ax=ax, transform=crs, vmin=vmin, vmax=vmax)
ds16m.mean_slac.plot(x='longitude', y='latitude',ax=ax, transform=crs, add_colorbar=False, vmin=vmin, vmax=vmax)
ax.set_title(f'Mean calibrated SLA over the Fast sampling period')
gl = ax.gridlines(draw_labels=True,)
ax.set_extent(bbox)
gl.top_labels = False
gl.right_labels = False


fig.tight_layout()
