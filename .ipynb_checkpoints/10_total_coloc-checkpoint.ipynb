# %% [markdown]
# ____
# # Colocalization dataset
# - put all variables for reconstruction in the same file

# %%
import numpy as np
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt

import os
from glob import glob

from cstes import swot_dir, drifters_dir, get_proj, lonlat2xy, zarr_dir, surface_drifters, depth_drifters, depth_100, depth_50
from swot import browse_swot_250, add_mask_inside_swot, build_swath_polygon

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.geodesic as cgeo
crs = ccrs.PlateCarree()

import cartopy.geodesic as geod
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import pyproj
from pyproj import Geod

from rasterio.transform import Affine

import pynsitu as pyn

c0 ={'acc':'#941717', 'coriolis':'#388E3C','ggrad':'#42A5F5', 'wind':'#FFA000'}
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="f6361731-dad5-4d7f-adb4-463005011d15" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"2d189e7b-6ef6-43f3-83c0-29222d0f7372":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"0df2fc120d004b5a80655dc40ddd985f","client_comm_id":"ff66f371479b4b6ba5efd1c878014daf"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"2d189e7b-6ef6-43f3-83c0-29222d0f7372","roots":{"p1002":"f6361731-dad5-4d7f-adb4-463005011d15"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Warning: could not import utide
# Warning: could not import pyTMD

# %% [markdown]
# _______
# # Data

# %%
drifters_sources = 'all_med_variational_10min_v0.nc'
#DRIFTERS = {'all_med_variational_10min_v0' : os.path.join(zarr_dir, 'drifters_all_med_variational_10min_v0.csv')}
drifter_file = os.path.join(zarr_dir, 'drifters_'+drifters_sources.replace('.nc', '.csv'))
ALTI = {
    'swot250naive' : os.path.join(zarr_dir, 'swot_250_'+drifters_sources.replace('.nc', '')+'_naive.csv'), 
    'swot250gauss1e3' : os.path.join(zarr_dir, 'swot_250_'+drifters_sources.replace('.nc', '')+'_gauss1e3.csv'), 
}
WIND = {'era5' : os.path.join(zarr_dir, 'era5_'+drifters_sources.replace('.nc', '')+'.csv')}

# %%
def prepared_drifters() : 
    dfr = pd.read_csv(drifter_file).set_index('row_number')
    dfr['f'] =  2 * 2 * np.pi / 86164.1 * np.sin(dfr.latitude * np.pi / 180)
    dfr['coriolise']= -dfr.f * dfr.velocity_north
    dfr['coriolisn']= dfr.f * dfr.velocity_east
    dfr = dfr.rename(columns = {'acceleration_north':'accn', 'acceleration_east':'acce'})
    return dfr[['datetime', 'longitude', 'latitude', 'pass_number','time_to_swot','cycle_number','cycle_date','drifter_id','drifter_type','accn', 'acce', 'coriolise', 'coriolisn']]

def prepared_alti(alti_key, ggrad_var=['duacs_ssha_karin_2_filtered','cvl_mean_dynamic_topography_cnes_cls_22','cvl_ocean_tide_fes_2022']) :
    dfs = pd.read_csv(ALTI[alti_key]).set_index('row_number')
    dfs['f'] =  2 * 2 * np.pi / 86164.1 * np.sin(dfs.latitude * np.pi / 180)
    dfs['ggrade_duacs'] = dfs.f * dfs.duacs_speed_meridional_abs
    dfs['ggradn_duacs'] = -dfs.f *dfs.duacs_speed_zonal_abs
    dfs = dfs[['ggrade_'+v for v in ggrad_var]+['ggradn_'+v for v in ggrad_var]+['ggrade_duacs', 'ggradn_duacs']]
    dfs['ggrade_etaf'] = dfs.ggrade_duacs_ssha_karin_2_filtered + dfs.ggrade_cvl_mean_dynamic_topography_cnes_cls_22+dfs.ggrade_cvl_ocean_tide_fes_2022
    dfs['ggradn_etaf'] = dfs.ggradn_duacs_ssha_karin_2_filtered + dfs.ggradn_cvl_mean_dynamic_topography_cnes_cls_22+dfs.ggradn_cvl_ocean_tide_fes_2022
    dfs['ggrade_adtf'] = dfs.ggrade_duacs_ssha_karin_2_filtered + dfs.ggrade_cvl_mean_dynamic_topography_cnes_cls_22
    dfs['ggradn_adtf'] = dfs.ggradn_duacs_ssha_karin_2_filtered + dfs.ggradn_cvl_mean_dynamic_topography_cnes_cls_22
    dfs['ggrade_etac'] = dfs.ggrade_duacs_ssha_karin_2_calibrated + dfs.ggrade_cvl_mean_dynamic_topography_cnes_cls_22+dfs.ggrade_cvl_ocean_tide_fes_2022
    dfs['ggradn_etac'] = dfs.ggradn_duacs_ssha_karin_2_calibrated + dfs.ggradn_cvl_mean_dynamic_topography_cnes_cls_22+dfs.ggradn_cvl_ocean_tide_fes_2022
    dfs['ggrade_adtc'] = dfs.ggrade_duacs_ssha_karin_2_calibrated + dfs.ggrade_cvl_mean_dynamic_topography_cnes_cls_22
    dfs['ggradn_adtc'] = dfs.ggradn_duacs_ssha_karin_2_calibrated + dfs.ggradn_cvl_mean_dynamic_topography_cnes_cls_22
    return dfs.rename(columns ={v : v+'_' +alti_key for v in dfs})
    
def prepared_wind(wind_key): 
    dfw = pd.read_csv(WIND[wind_key]).set_index('row_number')
    dfw = dfw[[v for v in dfw if ('winde' in v or 'windn' in v)]]
    return dfw.rename(columns ={v : v+'_' +wind_key for v in dfw})

# %%
df = pd.concat([prepared_drifters(), prepared_alti('swot250naive'), prepared_alti('swot250gauss1e3'), prepared_wind('era5')], axis=1).dropna()
#df.isnull().sum(axis=0) count nan before drop
#depth
depth = df['pass_number'].copy()
depth.loc[df['drifter_type'].isin(surface_drifters)]=0
depth.loc[df['drifter_type'].isin(depth_drifters)]=15
depth.loc[df['drifter_id'].isin(depth_50)]=50
depth.loc[df['drifter_id'].isin(depth_100)]=100

df['depth'] = depth
# Out:
# /var/folders/fn/z858c2qj1lz65xr0z5mdvbf40000gp/T/ipykernel_24339/2144714073.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfr = pd.read_csv(drifter_file).set_index('row_number')

# %%
df
# Out:
#                        datetime  longitude   latitude  pass_number  \
# row_number
# 0           2023-04-01 11:50:00   4.811970  42.220893            3
# 1           2023-04-01 12:00:00   4.812432  42.221430            3
# 2           2023-04-01 12:10:00   4.812916  42.221930            3
# 3           2023-04-01 12:20:00   4.813418  42.222394            3
# 4           2023-04-01 12:30:00   4.813933  42.222825            3
# ...                         ...        ...        ...          ...
# 383115      2023-07-10 06:10:00   2.018506  41.064216           16
# 383116      2023-07-10 06:20:00   2.016930  41.063339           16
# 383117      2023-07-10 06:30:00   2.015313  41.062462           16
# 383118      2023-07-10 06:40:00   2.013655  41.061590           16
# 383119      2023-07-10 06:50:00   2.011958  41.060728           16
#
#                          time_to_swot  cycle_number  \
# row_number
# 0              0 days 11:52:32.696536           478
# 1              0 days 11:42:32.696536           478
# 2              0 days 11:32:32.696536           478
# 3              0 days 11:22:32.696536           478
# 4              0 days 11:12:32.696536           478
# ...                               ...           ...
# 383115      0 days 11:13:38.131544384           577
# 383116      0 days 11:23:38.131544384           577
# 383117      0 days 11:33:38.131544384           577
# 383118      0 days 11:43:38.131544384           577
# 383119      0 days 11:53:38.131544384           577
#
#                                cycle_date       drifter_id drifter_type  \
# row_number
# 0           2023-04-01 23:42:32.696536000  300534060315840          SVP
# 1           2023-04-01 23:42:32.696536000  300534060315840          SVP
# 2           2023-04-01 23:42:32.696536000  300534060315840          SVP
# 3           2023-04-01 23:42:32.696536000  300534060315840          SVP
# 4           2023-04-01 23:42:32.696536000  300534060315840          SVP
# ...                                   ...              ...          ...
# 383115      2023-07-09 18:56:21.868455616              295       HEREON
# 383116      2023-07-09 18:56:21.868455616              295       HEREON
# 383117      2023-07-09 18:56:21.868455616              295       HEREON
# 383118      2023-07-09 18:56:21.868455616              295       HEREON
# 383119      2023-07-09 18:56:21.868455616              295       HEREON
#
#                     accn  ...  ggradn_cvl_ocean_tide_fes_2022_swot250gauss1e3  \
# row_number                ...
# 0          -1.210825e-05  ...                                   -4.385490e-07
# 1          -1.164980e-05  ...                                   -4.387752e-07
# 2          -1.101775e-05  ...                                   -4.388416e-07
# 3          -1.021439e-05  ...                                   -4.389345e-07
# 4          -9.243753e-06  ...                                   -4.390332e-07
# ...                  ...  ...                                             ...
# 383115     -1.529468e-06  ...                                   -6.926424e-07
# 383116     -1.470997e-08  ...                                   -6.925252e-07
# 383117      1.507983e-06  ...                                   -6.932690e-07
# 383118      3.014033e-06  ...                                   -6.943360e-07
# 383119      4.483105e-06  ...                                   -6.961480e-07
#
#             ggrade_duacs_swot250gauss1e3  ggradn_duacs_swot250gauss1e3  \
# row_number
# 0                               0.000019                  1.332680e-05
# 1                               0.000017                  1.269231e-05
# 2                               0.000015                  1.320000e-05
# 3                               0.000010                  1.263890e-05
# 4                               0.000008                  1.051351e-05
# ...                                  ...                           ...
# 383115                         -0.000021                  3.379388e-06
# 383116                         -0.000022                  6.481391e-06
# 383117                         -0.000026                  2.739680e-06
# 383118                         -0.000030                 -5.245928e-07
# 383119                         -0.000027                 -7.551510e-06
#
#             ggrade_eta_swot250gauss1e3  ggradn_eta_swot250gauss1e3  \
# row_number
# 0                             0.000015                    0.000010
# 1                             0.000016                    0.000010
# 2                             0.000016                    0.000010
# 3                             0.000016                    0.000010
# 4                             0.000016                    0.000010
# ...                                ...                         ...
# 383115                       -0.000028                   -0.000003
# 383116                       -0.000029                   -0.000003
# 383117                       -0.000029                   -0.000003
# 383118                       -0.000029                   -0.000003
# 383119                       -0.000029                   -0.000003
#
#             winde0_era5  windn0_era5  winde15_era5  windn15_era5  depth
# row_number
# 0             -0.000013    -0.000007 -3.642340e-06 -8.342680e-07     15
# 1             -0.000013    -0.000007 -3.531180e-06 -8.430640e-07     15
# 2             -0.000012    -0.000007 -3.377912e-06 -8.287643e-07     15
# 3             -0.000012    -0.000006 -3.224727e-06 -8.143826e-07     15
# 4             -0.000011    -0.000006 -3.071636e-06 -7.999297e-07     15
# ...                 ...          ...           ...           ...    ...
# 383115        -0.000002     0.000003 -3.687235e-07  7.542479e-07      0
# 383116        -0.000002     0.000003 -3.635672e-07  7.797619e-07      0
# 383117        -0.000002     0.000003 -3.581426e-07  8.048202e-07      0
# 383118        -0.000002     0.000003 -3.524521e-07  8.294139e-07      0
# 383119        -0.000002     0.000003 -3.465011e-07  8.535396e-07      0
#
# [332818 rows x 38 columns]

# %%
# select only nearest in time colocalisation
def select_nearest_swot_coloc(df):
    idx = df.groupby(['pass_number','cycle_number','drifter_id']).time_to_swot.idxmin()
    return df.loc[idx]

dfc = select_nearest_swot_coloc(df).dropna()
dfc
# Out:
#                        datetime  longitude   latitude  pass_number  \
# row_number
# 214         2023-04-01 23:40:00   5.632249  42.255307            3
# 727         2023-04-02 01:40:00   5.243148  42.903938            3
# 1001        2023-04-01 23:40:00   5.558617  42.880708            3
# 500         2023-04-01 23:40:00   4.773443  42.198418            3
# 858         2023-04-01 23:40:00   5.600033  41.562868            3
# ...                         ...        ...        ...          ...
# 383048      2023-07-09 19:00:00   2.122807  41.093707           16
# 382230      2023-07-09 22:40:00   1.552078  40.941677           16
# 382905      2023-07-09 19:00:00   1.794712  39.114167           16
# 382476      2023-07-09 19:00:00   1.789264  39.325744           16
# 382304      2023-07-09 11:10:00   1.748373  38.381312           16
#
#                          time_to_swot  cycle_number  \
# row_number
# 214            0 days 00:02:32.696536           478
# 727            0 days 01:57:27.303464           478
# 1001           0 days 00:02:32.696536           478
# 500            0 days 00:02:32.696536           478
# 858            0 days 00:02:32.696536           478
# ...                               ...           ...
# 383048      0 days 00:03:38.131544384           577
# 382230      0 days 03:43:38.131544384           577
# 382905      0 days 00:03:38.131544384           577
# 382476      0 days 00:03:38.131544384           577
# 382304      0 days 07:46:21.868455616           577
#
#                                cycle_date       drifter_id drifter_type  \
# row_number
# 214         2023-04-01 23:42:32.696536000        0-4351296       CARTHE
# 727         2023-04-01 23:42:32.696536000        0-4388554       CARTHE
# 1001        2023-04-01 23:42:32.696536000        0-4388557       CARTHE
# 500         2023-04-01 23:42:32.696536000        0-4388599       CARTHE
# 858         2023-04-01 23:42:32.696536000                2       MELODI
# ...                                   ...              ...          ...
# 383048      2023-07-09 18:56:21.868455616              295       HEREON
# 382230      2023-07-09 18:56:21.868455616          4694223       CARTHE
# 382905      2023-07-09 18:56:21.868455616          6204608         OSMC
# 382476      2023-07-09 18:56:21.868455616  300534060211000          SVP
# 382304      2023-07-09 18:56:21.868455616  300534060218400          SVP
#
#                 accn  ...  ggradn_cvl_ocean_tide_fes_2022_swot250gauss1e3  \
# row_number            ...
# 214        -0.000023  ...                                   -4.378941e-07
# 727        -0.000004  ...                                   -5.910732e-07
# 1001       -0.000003  ...                                   -5.680131e-07
# 500         0.000003  ...                                   -4.473702e-07
# 858        -0.000010  ...                                   -4.428720e-07
# ...              ...  ...                                             ...
# 383048     -0.000010  ...                                   -7.280843e-07
# 382230      0.000003  ...                                   -7.703162e-07
# 382905      0.000018  ...                                   -1.372612e-06
# 382476      0.000005  ...                                   -1.144106e-06
# 382304      0.000021  ...                                   -1.019729e-06
#
#             ggrade_duacs_swot250gauss1e3  ggradn_duacs_swot250gauss1e3  \
# row_number
# 214                            -0.000022                     -0.000015
# 727                            -0.000028                      0.000032
# 1001                           -0.000032                      0.000027
# 500                            -0.000011                      0.000007
# 858                            -0.000010                      0.000038
# ...                                  ...                           ...
# 383048                          0.000010                      0.000011
# 382230                         -0.000010                      0.000021
# 382905                          0.000010                     -0.000023
# 382476                          0.000005                     -0.000009
# 382304                          0.000011                     -0.000015
#
#             ggrade_eta_swot250gauss1e3  ggradn_eta_swot250gauss1e3  \
# row_number
# 214                      -1.715840e-05                   -0.000005
# 727                      -2.604908e-05                    0.000025
# 1001                     -2.318289e-05                    0.000026
# 500                       1.467713e-05                    0.000008
# 858                      -3.930858e-06                    0.000020
# ...                                ...                         ...
# 383048                    1.151805e-05                    0.000011
# 382230                   -1.223015e-05                    0.000010
# 382905                    1.193887e-05                   -0.000030
# 382476                    3.139310e-06                   -0.000011
# 382304                    2.517520e-07                   -0.000012
#
#              winde0_era5   windn0_era5  winde15_era5  windn15_era5  depth
# row_number
# 214        -2.743812e-05 -1.816019e-05 -7.800848e-06 -2.609972e-06      0
# 727        -3.208626e-05 -1.407504e-05 -8.658959e-06 -1.322728e-06      0
# 1001       -2.581363e-05 -1.853904e-05 -7.433077e-06 -2.806569e-06      0
# 500        -3.597150e-05 -1.654748e-05 -9.757152e-06 -1.668382e-06      0
# 858        -2.165497e-05 -1.082177e-05 -5.929494e-06 -1.212077e-06      0
# ...                  ...           ...           ...           ...    ...
# 383048      9.494988e-08  6.632627e-07  6.584489e-08  1.540219e-07      0
# 382230      5.884896e-07  1.531490e-06  2.412040e-07  3.317483e-07      0
# 382905      6.074151e-07  9.681990e-07  2.093266e-07  1.944995e-07     15
# 382476      3.840626e-07  9.438870e-07  1.538180e-07  2.030805e-07     15
# 382304      2.863134e-07 -1.773632e-07  5.766314e-08 -6.135576e-08     15
#
# [2665 rows x 38 columns]

# %%
df.to_csv(os.path.join(zarr_dir, 'coloc_all.csv'))
dfc.to_csv(os.path.join(zarr_dir, 'coloc_nearest.csv'))

# %%
dfc
# Out:
#                        datetime  longitude   latitude  pass_number  \
# row_number
# 214         2023-04-01 23:40:00   5.632249  42.255307            3
# 727         2023-04-02 01:40:00   5.243148  42.903938            3
# 1001        2023-04-01 23:40:00   5.558617  42.880708            3
# 500         2023-04-01 23:40:00   4.773443  42.198418            3
# 858         2023-04-01 23:40:00   5.600033  41.562868            3
# ...                         ...        ...        ...          ...
# 383048      2023-07-09 19:00:00   2.122807  41.093707           16
# 382230      2023-07-09 22:40:00   1.552078  40.941677           16
# 382905      2023-07-09 19:00:00   1.794712  39.114167           16
# 382476      2023-07-09 19:00:00   1.789264  39.325744           16
# 382304      2023-07-09 11:10:00   1.748373  38.381312           16
#
#                          time_to_swot  cycle_number  \
# row_number
# 214            0 days 00:02:32.696536           478
# 727            0 days 01:57:27.303464           478
# 1001           0 days 00:02:32.696536           478
# 500            0 days 00:02:32.696536           478
# 858            0 days 00:02:32.696536           478
# ...                               ...           ...
# 383048      0 days 00:03:38.131544384           577
# 382230      0 days 03:43:38.131544384           577
# 382905      0 days 00:03:38.131544384           577
# 382476      0 days 00:03:38.131544384           577
# 382304      0 days 07:46:21.868455616           577
#
#                                cycle_date       drifter_id drifter_type  \
# row_number
# 214         2023-04-01 23:42:32.696536000        0-4351296       CARTHE
# 727         2023-04-01 23:42:32.696536000        0-4388554       CARTHE
# 1001        2023-04-01 23:42:32.696536000        0-4388557       CARTHE
# 500         2023-04-01 23:42:32.696536000        0-4388599       CARTHE
# 858         2023-04-01 23:42:32.696536000                2       MELODI
# ...                                   ...              ...          ...
# 383048      2023-07-09 18:56:21.868455616              295       HEREON
# 382230      2023-07-09 18:56:21.868455616          4694223       CARTHE
# 382905      2023-07-09 18:56:21.868455616          6204608         OSMC
# 382476      2023-07-09 18:56:21.868455616  300534060211000          SVP
# 382304      2023-07-09 18:56:21.868455616  300534060218400          SVP
#
#                 accn  ...  ggradn_cvl_ocean_tide_fes_2022_swot250gauss1e3  \
# row_number            ...
# 214        -0.000023  ...                                   -4.378941e-07
# 727        -0.000004  ...                                   -5.910732e-07
# 1001       -0.000003  ...                                   -5.680131e-07
# 500         0.000003  ...                                   -4.473702e-07
# 858        -0.000010  ...                                   -4.428720e-07
# ...              ...  ...                                             ...
# 383048     -0.000010  ...                                   -7.280843e-07
# 382230      0.000003  ...                                   -7.703162e-07
# 382905      0.000018  ...                                   -1.372612e-06
# 382476      0.000005  ...                                   -1.144106e-06
# 382304      0.000021  ...                                   -1.019729e-06
#
#             ggrade_duacs_swot250gauss1e3  ggradn_duacs_swot250gauss1e3  \
# row_number
# 214                            -0.000022                     -0.000015
# 727                            -0.000028                      0.000032
# 1001                           -0.000032                      0.000027
# 500                            -0.000011                      0.000007
# 858                            -0.000010                      0.000038
# ...                                  ...                           ...
# 383048                          0.000010                      0.000011
# 382230                         -0.000010                      0.000021
# 382905                          0.000010                     -0.000023
# 382476                          0.000005                     -0.000009
# 382304                          0.000011                     -0.000015
#
#             ggrade_eta_swot250gauss1e3  ggradn_eta_swot250gauss1e3  \
# row_number
# 214                      -1.715840e-05                   -0.000005
# 727                      -2.604908e-05                    0.000025
# 1001                     -2.318289e-05                    0.000026
# 500                       1.467713e-05                    0.000008
# 858                      -3.930858e-06                    0.000020
# ...                                ...                         ...
# 383048                    1.151805e-05                    0.000011
# 382230                   -1.223015e-05                    0.000010
# 382905                    1.193887e-05                   -0.000030
# 382476                    3.139310e-06                   -0.000011
# 382304                    2.517520e-07                   -0.000012
#
#              winde0_era5   windn0_era5  winde15_era5  windn15_era5  depth
# row_number
# 214        -2.743812e-05 -1.816019e-05 -7.800848e-06 -2.609972e-06      0
# 727        -3.208626e-05 -1.407504e-05 -8.658959e-06 -1.322728e-06      0
# 1001       -2.581363e-05 -1.853904e-05 -7.433077e-06 -2.806569e-06      0
# 500        -3.597150e-05 -1.654748e-05 -9.757152e-06 -1.668382e-06      0
# 858        -2.165497e-05 -1.082177e-05 -5.929494e-06 -1.212077e-06      0
# ...                  ...           ...           ...           ...    ...
# 383048      9.494988e-08  6.632627e-07  6.584489e-08  1.540219e-07      0
# 382230      5.884896e-07  1.531490e-06  2.412040e-07  3.317483e-07      0
# 382905      6.074151e-07  9.681990e-07  2.093266e-07  1.944995e-07     15
# 382476      3.840626e-07  9.438870e-07  1.538180e-07  2.030805e-07     15
# 382304      2.863134e-07 -1.773632e-07  5.766314e-08 -6.135576e-08     15
#
# [2665 rows x 38 columns]

# %%
def find_combination(df):
    id_comb = []
    # Alti
    ggrade, ggradn = [v for v in df if 'ggrade' in v], [v for v in df if 'ggradn' in v]
    alti_var = [v.replace('ggrade_','') for v in ggrade]
    
    # Wind
    winde, windn = [v for v in df if 'winde' in v], [v for v in df if 'windn' in v]
    wind_var = [v.replace('winde','').replace('_', '') for v in winde]

    import itertools  

    couple = list(itertools.product(alti_var, wind_var))
    E, N = list(itertools.product(ggrade, winde)), list(itertools.product(ggradn, windn))
    
    id_comb = dict()
    for i in range(len(E)):
        le = {"acc" : "acce", "coriolis" : "coriolise", "ggrad":E[i][0], "wind":E[i][1]}
        ln = {"acc" : "accn", "coriolis" : "coriolisn", "ggrad":N[i][0], "wind":N[i][1]}
        id_comb['__'.join(couple[i])] = le, ln
    return id_comb

# %%
id_comb = find_combination(dfc)
id_comb
# Out:
# {'duacs_ssha_karin_2_filtered_swot250naive__0era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_duacs_ssha_karin_2_filtered_swot250naive',
#    'wind': 'winde0_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_duacs_ssha_karin_2_filtered_swot250naive',
#    'wind': 'windn0_era5'}),
#  'duacs_ssha_karin_2_filtered_swot250naive__15era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_duacs_ssha_karin_2_filtered_swot250naive',
#    'wind': 'winde15_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_duacs_ssha_karin_2_filtered_swot250naive',
#    'wind': 'windn15_era5'}),
#  'cvl_mean_dynamic_topography_cnes_cls_22_swot250naive__0era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_cvl_mean_dynamic_topography_cnes_cls_22_swot250naive',
#    'wind': 'winde0_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_cvl_mean_dynamic_topography_cnes_cls_22_swot250naive',
#    'wind': 'windn0_era5'}),
#  'cvl_mean_dynamic_topography_cnes_cls_22_swot250naive__15era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_cvl_mean_dynamic_topography_cnes_cls_22_swot250naive',
#    'wind': 'winde15_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_cvl_mean_dynamic_topography_cnes_cls_22_swot250naive',
#    'wind': 'windn15_era5'}),
#  'cvl_ocean_tide_fes_2022_swot250naive__0era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_cvl_ocean_tide_fes_2022_swot250naive',
#    'wind': 'winde0_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_cvl_ocean_tide_fes_2022_swot250naive',
#    'wind': 'windn0_era5'}),
#  'cvl_ocean_tide_fes_2022_swot250naive__15era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_cvl_ocean_tide_fes_2022_swot250naive',
#    'wind': 'winde15_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_cvl_ocean_tide_fes_2022_swot250naive',
#    'wind': 'windn15_era5'}),
#  'duacs_swot250naive__0era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_duacs_swot250naive',
#    'wind': 'winde0_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_duacs_swot250naive',
#    'wind': 'windn0_era5'}),
#  'duacs_swot250naive__15era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_duacs_swot250naive',
#    'wind': 'winde15_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_duacs_swot250naive',
#    'wind': 'windn15_era5'}),
#  'eta_swot250naive__0era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_eta_swot250naive',
#    'wind': 'winde0_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_eta_swot250naive',
#    'wind': 'windn0_era5'}),
#  'eta_swot250naive__15era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_eta_swot250naive',
#    'wind': 'winde15_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_eta_swot250naive',
#    'wind': 'windn15_era5'}),
#  'duacs_ssha_karin_2_filtered_swot250gauss1e3__0era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_duacs_ssha_karin_2_filtered_swot250gauss1e3',
#    'wind': 'winde0_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_duacs_ssha_karin_2_filtered_swot250gauss1e3',
#    'wind': 'windn0_era5'}),
#  'duacs_ssha_karin_2_filtered_swot250gauss1e3__15era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_duacs_ssha_karin_2_filtered_swot250gauss1e3',
#    'wind': 'winde15_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_duacs_ssha_karin_2_filtered_swot250gauss1e3',
#    'wind': 'windn15_era5'}),
#  'cvl_mean_dynamic_topography_cnes_cls_22_swot250gauss1e3__0era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_cvl_mean_dynamic_topography_cnes_cls_22_swot250gauss1e3',
#    'wind': 'winde0_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_cvl_mean_dynamic_topography_cnes_cls_22_swot250gauss1e3',
#    'wind': 'windn0_era5'}),
#  'cvl_mean_dynamic_topography_cnes_cls_22_swot250gauss1e3__15era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_cvl_mean_dynamic_topography_cnes_cls_22_swot250gauss1e3',
#    'wind': 'winde15_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_cvl_mean_dynamic_topography_cnes_cls_22_swot250gauss1e3',
#    'wind': 'windn15_era5'}),
#  'cvl_ocean_tide_fes_2022_swot250gauss1e3__0era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_cvl_ocean_tide_fes_2022_swot250gauss1e3',
#    'wind': 'winde0_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_cvl_ocean_tide_fes_2022_swot250gauss1e3',
#    'wind': 'windn0_era5'}),
#  'cvl_ocean_tide_fes_2022_swot250gauss1e3__15era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_cvl_ocean_tide_fes_2022_swot250gauss1e3',
#    'wind': 'winde15_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_cvl_ocean_tide_fes_2022_swot250gauss1e3',
#    'wind': 'windn15_era5'}),
#  'duacs_swot250gauss1e3__0era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_duacs_swot250gauss1e3',
#    'wind': 'winde0_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_duacs_swot250gauss1e3',
#    'wind': 'windn0_era5'}),
#  'duacs_swot250gauss1e3__15era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_duacs_swot250gauss1e3',
#    'wind': 'winde15_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_duacs_swot250gauss1e3',
#    'wind': 'windn15_era5'}),
#  'eta_swot250gauss1e3__0era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_eta_swot250gauss1e3',
#    'wind': 'winde0_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_eta_swot250gauss1e3',
#    'wind': 'windn0_era5'}),
#  'eta_swot250gauss1e3__15era5': ({'acc': 'acce',
#    'coriolis': 'coriolise',
#    'ggrad': 'ggrade_eta_swot250gauss1e3',
#    'wind': 'winde15_era5'},
#   {'acc': 'accn',
#    'coriolis': 'coriolisn',
#    'ggrad': 'ggradn_eta_swot250gauss1e3',
#    'wind': 'windn15_era5'})}

# %%
def compute(df, id_comb):
    D = []
    for comb in id_comb :
        coords_list = ['datetime', 'longitude', 'latitude', 'pass_number','time_to_swot','cycle_number','drifter_id', 'drifter_type']
        ds = df[coords_list].to_xarray()
        import itertools
        ds['id_comb'] = comb
        
        for direction in ['e', 'n'] : 
            if direction == 'e' : l = id_comb[comb][0]
            if direction == 'n' : l = id_comb[comb][1]
                
            # sum 
            ds['sum'+direction] = sum([df[v] for v in l.values()])

            # simple var + sum- one term
            for v in list(l.keys()) : 
                ds[v+direction] = df[l[v]]
                ds['exc'+direction+'_'+v] = ds['sum'+direction]-ds[v+direction]
                
            #2 by 2 product    
            couple = list(itertools.combinations(list(l.keys()),2))
            for c in couple : 
                ds['prod'+direction+'_'+'_'.join(c)] = ds[c[0]+direction] * ds[c[1]+direction]
                
        D.append(ds)
    DS = xr.concat(D, dim='id_comb').set_coords(coords_list)
    return DS

# %%
DS = compute(dfc, id_comb)
DSS = DS.where(DS.drifter_type.isin(surface_drifters), drop=True)
DSD = DS.where(DS.drifter_type.isin(depth_drifters), drop=True)
# Out:
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/core/dataset.py:4789: UserWarning: No index created for dimension id_comb because variable id_comb is not a coordinate. To create an index for id_comb, please first call `.set_coords('id_comb')` on this object.
#   warnings.warn(

# %%
DS['drifter_id'] = DS.drifter_id.astype(str)

# %%
DS.to_netcdf(os.path.join(zarr_dir, 'coloc_closure.nc'))

# %%
idc = ['duacs_swot250naive__0era5', 'duacs_swot250naive__15era5', 'eta_swot250naive__0era5', 'eta_swot250naive__15era5', 'duacs_swot250gauss1e3__0era5', 'duacs_swot250gauss1e3__15era5','eta_swot250gauss1e3__0era5', 'eta_swot250gauss1e3__15era5']
((DS.sume**2).sel(id_comb =idc).mean('row_number')).plot()
plt.xticks(rotation=30, ha='right')
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'duacs_swot250naive__0era5'),
#   Text(1, 0, 'duacs_swot250naive__15era5'),
#   Text(2, 0, 'eta_swot250naive__0era5'),
#   Text(3, 0, 'eta_swot250naive__15era5'),
#   Text(4, 0, 'duacs_swot250gauss1e3__0era5'),
#   Text(5, 0, 'duacs_swot250gauss1e3__15era5'),
#   Text(6, 0, 'eta_swot250gauss1e3__0era5'),
#   Text(7, 0, 'eta_swot250gauss1e3__15era5')])
