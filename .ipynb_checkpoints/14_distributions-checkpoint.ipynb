# %%
import numpy as np
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt

import os
from glob import glob

from cstes import swot_dir, drifters_dir, get_proj, lonlat2xy, zarr_dir, surface_drifters, depth_drifters, depth_100, depth_50, images_dir, U2, err_acc
from swot import browse_swot_250, add_mask_inside_swot, build_swath_polygon, browse_swot_2km
from diagnosis import dataset_coloc_combs, DRIFTER, ALTI, WD, prepared_drifters, prepared_wd, prepared_alti

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.geodesic as cgeo
crs = ccrs.PlateCarree()

import cartopy.geodesic as geod
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import pyproj
from pyproj import Geod

from rasterio.transform import Affine

import pynsitu as pyn

from diagnosis import synthetic_figure
from cstes import U2, c0, U
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c03662b8-c786-49c1-9101-6b57215f5dec" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# _______
# # Data

# %%
DRIFTER.keys(), ALTI.keys(), WD.keys()
# wd_depth = '0' or '15'
# ggd_var = 'etaf', 'etac', 'adtf', 'adtc', 'fromduacsv'
# Out:
# (dict_keys(['nofilter', '0.5cpd', '1.5cpd', '2.5cpd', '3cpd']),
#  dict_keys(['swot250naive', 'swot250gauss1e3', 'swot250gauss2e3', 'swot250gauss3e3', 'swot250gauss4e3', 'swot250gauss5e3', 'swot2kmnaive', 'swot2kmgauss1e3', 'swot2kmgauss2e3', 'swot2kmgauss3e3', 'swot2kmgauss4e3', 'swot2kmgauss5e3', 'swot2kmgauss1e4']),
#  dict_keys(['era5']))

# %%
comb_list = [dict(drifter_key='nofilter', alti_key = 'swot2kmnaive', wd_key = 'era5', ggd_var='etaf', wd_depth='0'), 
            dict(drifter_key='nofilter', alti_key = 'swot2kmnaive', wd_key = 'era5', ggd_var='etaf', wd_depth='15')]
DS = dataset_coloc_combs(comb_list, nearest =False).drop_sel(row_number = err_acc)
DSS = DS.where(DS.depth==0, drop=True).isel(id_comb=0)
DSD = DS.where(DS.depth==15, drop=True).isel(id_comb=1)

# %% [markdown]
# ______
# # Distribution

# %%
q = 0.995

# %%
fig, axs = plt.subplots(nrows=2, ncols=6, figsize=(18, 10))
axs =axs.flatten()

r=10

s = abs(DSS.sume*r)
c = abs(DSS.sume*r)
DSS.plot.scatter(x='acce', y='core', s = s,c=c, ax=axs[0])
DSS.plot.scatter(x='acce', y='ggde', s = s,c=c, ax=axs[1])
DSS.plot.scatter(x='acce', y='wde', s = s,c=c, ax=axs[2])
DSS.plot.scatter(x='core', y='ggde', s = s,c=c, ax=axs[3])
DSS.plot.scatter(x='core', y='wde', s = s,c=c, ax=axs[4])
DSS.plot.scatter(x='ggde', y='wde', s = s,c=c, ax=axs[5])

s=3
pb = DSS.where(abs(DSS.sume)>abs(DSS.sume).quantile(q), drop=True)
pb.plot.scatter(x='acce', y='core',marker='x', s = s,c='r', ax=axs[0])
pb.plot.scatter(x='acce', y='ggde',marker='x', s = s,c='r', ax=axs[1])
pb.plot.scatter(x='acce', y='wde',marker='x', s = s,c='r', ax=axs[2])
pb.plot.scatter(x='core', y='ggde',marker='x', s = s,c='r', ax=axs[3])
pb.plot.scatter(x='core', y='wde',marker='x', s = s,c='r', ax=axs[4])
pb.plot.scatter(x='ggde', y='wde',marker='x', s = s,c='r', ax=axs[5])

s = abs(DSS.sumn*r)
c = abs(DSS.sumn*r)
DSS.plot.scatter(x='accn', y='corn', s = s,c=c, ax=axs[6])
DSS.plot.scatter(x='accn', y='ggdn', s = s,c=c, ax=axs[7])
DSS.plot.scatter(x='accn', y='wdn', s = s,c=c, ax=axs[8])
DSS.plot.scatter(x='corn', y='ggdn', s = s,c=c, ax=axs[9])
DSS.plot.scatter(x='corn', y='wdn', s = s,c=c, ax=axs[10])
DSS.plot.scatter(x='ggdn', y='wdn', s = s,c=c, ax=axs[11])

s=3
pb = DSS.where(abs(DSS.sumn)>abs(DSS.sumn).quantile(q), drop=True)
pb.plot.scatter(x='accn', y='corn',marker='x', s = s,c='r', ax=axs[6])
pb.plot.scatter(x='accn', y='ggdn',marker='x', s = s,c='r', ax=axs[7])
pb.plot.scatter(x='accn', y='wdn',marker='x', s = s,c='r', ax=axs[8])
pb.plot.scatter(x='corn', y='ggdn',marker='x', s = s,c='r', ax=axs[9])
pb.plot.scatter(x='corn', y='wdn',marker='x', s = s,c='r', ax=axs[10])
pb.plot.scatter(x='ggdn', y='wdn',marker='x', s = s,c='r', ax=axs[11])

x = np.arange(-1e-5/U, 1e-5/U, 1e-6/U)
for ax in axs:
    ax.grid()
    ax.set_title('')
    ax.plot(x, x, c='grey')
    ax.plot(x, -x, c='grey')

fig.tight_layout()

# %%
fig, axs = plt.subplots(nrows=2, ncols=6, figsize=(18, 10))
axs =axs.flatten()

r=10
s = abs(DSD.sume*r)
c = abs(DSD.sume*r)

DSD.plot.scatter(x='acce', y='core', s = s,c=c, ax=axs[0])
DSD.plot.scatter(x='acce', y='ggde', s = s,c=c, ax=axs[1])
DSD.plot.scatter(x='acce', y='wde', s = s,c=c, ax=axs[2])
DSD.plot.scatter(x='core', y='ggde', s = s,c=c, ax=axs[3])
DSD.plot.scatter(x='core', y='wde', s = s,c=c, ax=axs[4])
DSD.plot.scatter(x='ggde', y='wde', s = s,c=c, ax=axs[5])

s = abs(DSD.sumn*r)
c = abs(DSD.sumn*r)
DSD.plot.scatter(x='accn', y='corn', s = s,c=c, ax=axs[6])
DSD.plot.scatter(x='accn', y='ggdn', s = s,c=c, ax=axs[7])
DSD.plot.scatter(x='accn', y='wdn', s = s,c=c, ax=axs[8])
DSD.plot.scatter(x='corn', y='ggdn', s = s,c=c, ax=axs[9])
DSD.plot.scatter(x='corn', y='wdn', s = s,c=c, ax=axs[10])
DSD.plot.scatter(x='ggdn', y='wdn', s = s,c=c, ax=axs[11])


x = np.arange(-1e-5/U, 1e-5/U, 1e-6/U)
for ax in axs:
    ax.grid()
    ax.plot(x, x, c='grey')
    ax.plot(x, -x, c='grey')
    
    ax.set_title('')

fig.tight_layout()

# %%
dss.where((dss.latitude>bbox[2]) & (dss.latitude<bbox[3])&(dss.longitude>bbox[0]) & (dss.longitude<bbox[1])).cvl_dac.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dss.where((dss.latitude>bbox[2]) & (dss.latitude<bbox[3])&(dss.longitude>bbox[0]) & (dss.longitude<bbox[1])).cvl_dac.plot()
#
# NameError: name 'dss' is not defined

# %% [markdown]
# _____
# # PB : higher values

# %%
dfc = (dataset_coloc_combs(comb_list, nearest =True).isel(id_comb=0)/U).to_dataframe()
dfw = prepared_wd('era5')
# Out:
# nofilter__swot2kmnaive_etaf__15era5

# %%
df = (dataset_coloc_combs(comb_list, nearest =False).isel(id_comb=0)/U).to_dataframe()
# Out:
# nofilter__swot2kmnaive_etaf__15era5

# %%
def plot_exemple(pb, directory):
    for rn in pb.row_number:
        pb_ = pb.sel(row_number=rn)

        dl = 0.2
        bbox = [pb_.longitude.values-dl, pb_.longitude.values+dl, pb_.latitude.values-dl, pb_.latitude.values+dl]
        
        dfc_ = dfc.where((dfc.pass_number==pb_.pass_number.values)&(dfc.cycle_number==pb_.cycle_number.values)&(dfc.drifter_id==pb_.drifter_id.values)).dropna()
        
        dfwc_ = dfw.loc[rn.values]

        df_ = df.where((df.pass_number==pb_.pass_number.values)&(df.cycle_number==pb_.cycle_number.values)&(df.drifter_id==pb_.drifter_id.values)).dropna()
        dfs = browse_swot_2km().reset_index()
        dss = xr.open_dataset(dfs.where((dfs.pass_number==pb_.pass_number.values)&(dfs.cycle_number==pb_.cycle_number.values)).dropna().file.values[0])
        dss = dss.where((dss.latitude>bbox[2]) & (dss.latitude<bbox[3])&(dss.longitude>bbox[0]) & (dss.longitude<bbox[1]))
        fig = plt.figure( frameon=False, figsize=(20,6))
        ax = fig.add_subplot(131, projection=ccrs.Orthographic(df.longitude.mean(), df.latitude.mean()))
        
        ax.add_feature(cfeature.LAND,)
        gl = ax.gridlines(draw_labels=True,)
        ax.set_extent(bbox)
        
        #SWOT
        dss['eta'] = dss.cvl_mean_dynamic_topography_cnes_cls_22 + dss.cvl_ocean_tide_fes_2022 + dss.duacs_ssha_karin_2_filtered
        dss.eta.plot(x='longitude', y='latitude', ax=ax, transform=crs,cmap='viridis')
    
        #ERA5
        #t = dss.time.mean()
        #era_ = era.sel(time=dss.time.mean(), method='nearest').sortby('latitude')
        #era_ = era_.sel(longitude=slice(bbox[0], bbox[1]), latitude=slice(bbox[2], bbox[3]))
        #Q = era_.plot.quiver('longitude', 'latitude', 'u10', 'v10', ax=ax, transform =crs, scale=250, color='magenta', clip_on = False, add_guide = False)
        
        #Drifters
        df_.plot.scatter('longitude', 'latitude', transform =crs, ax=ax, s=2 )
        dfc_.plot.scatter('longitude', 'latitude', transform =crs, ax=ax, marker='*', color='r', s=10 )
    
        ax = fig.add_subplot(132)
        df_['sume'] = df_.acce + df_.core + df_.ggde + df_.wde
        df_ = df_.set_index('datetime')
        df_.acce.plot(ax=ax, label = 'acc', c=c0['acc'], ls='', marker='.')
        df_.core.plot(ax=ax, c=c0['cor'], label = 'cor', ls='', marker='.')
        df_.ggde.plot(ax=ax,c=c0['ggd'],  label = 'ggd', ls='', marker='.')
        df_.wde.plot(ax=ax,c=c0['wd'],  label = 'wd', ls='', marker='.')
        df_.sume.plot(ax=ax, c='k', label = 's', ls='--')
        ax.axvline(dfc_.datetime.values[0], color = 'r',ls=':')
        ax.axvline(dss.time.mean().values, color = 'b',ls=':')
        ax.legend()
        ax.grid()
        #ax.set_ylim(-7e-5, 7e-5)
    
    
        ax = fig.add_subplot(133)
        df_['sumn'] = df_.accn + df_.corn + df_.ggdn + df_.wdn
        df_.accn.plot(ax=ax, label = 'acc', c=c0['acc'], ls='', marker='.')
        df_.corn.plot(ax=ax, c=c0['cor'], label = 'cor', ls='', marker='.')
        df_.ggdn.plot(ax=ax,c=c0['ggd'],  label = 'ggd', ls='', marker='.')
        df_.wdn.plot(ax=ax,c=c0['wd'],  label = 'wd', ls='', marker='.')
        df_.sumn.plot(ax=ax, c='k', label = 's', ls='--')
        ax.axvline(dfc_.datetime.values[0], color = 'r',ls=':')
        ax.axvline(dss.time.mean().values, color = 'b',ls=':')
        ax.legend()
        ax.grid()
        #ax.set_ylim(-7e-5, 7e-5)
    
        fig.suptitle(f'{pb_.row_number.values}, {pb_.pass_number.values}, {pb_.cycle_number.values}, {pb_.drifter_type.values}, {pb_.drifter_id.values} \n'+ f', idcomb ={DSD.id_comb.values}' )#+ f'wd ={np.sqrt(dfwc_.u10**2 + dfwc_.v10**2)}'
        fig.savefig(os.path.join(images_dir, directory, f'{rn.values}.png'), dpi=200, bbox_inches='tight')

# %%
pb = DSS.where((abs(DSS.sume)>abs(DSS.sume).quantile(q))| (abs(DSS.sumn)>abs(DSS.sumn).quantile(q)), drop=True)
plot_exemple(pb, 'exemples_highS')
# Out:
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# ...

# %%
pb = DSS.where((abs(DSS.sume)<abs(DSS.sume).quantile(1-q))| (abs(DSS.sumn)<abs(DSS.sumn).quantile(1-q)), drop=True)
plot_exemple(pb, 'exemples_lowS')
# Out:
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# ...

# %%
pb = DSD.where((abs(DSD.sume)>abs(DSD.sume).quantile(q))| (abs(DSD.sumn)>abs(DSD.sumn).quantile(q)), drop=True)
plot_exemple(pb, 'exemples_highS')
# Out:
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# ...

# %%
pb = DSD.where((abs(DSD.sume)<abs(DSD.sume).quantile(1-q))| (abs(DSD.sumn)<abs(DSD.sumn).quantile(1-q)), drop=True)
plot_exemple(pb, 'exemples_lowS')
# Out:
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# ...

# %% [markdown]
# # Where are they

# %%
dfs = browse_swot_2km().reset_index()

# %%
pb = DSS.where((abs(DSS.sume)>abs(DSS.sume).quantile(q))| (abs(DSS.sumn)>abs(DSS.sumn).quantile(q)), drop=True)
dss3 = xr.open_dataset(dfs.where((dfs.pass_number==3)&(dfs.cycle_number==500)).dropna().file.values[0])
dss3.cvl_mean_dynamic_topography_cnes_cls_22.plot(x='longitude', y='latitude')
dss16 = xr.open_dataset(dfs.where((dfs.pass_number==16)&(dfs.cycle_number==500)).dropna().file.values[0])
dss16.cvl_mean_dynamic_topography_cnes_cls_22.plot(x='longitude', y='latitude')
pb = DSS.where((abs(DSS.sume)>abs(DSS.sume).quantile(q))| (abs(DSS.sumn)>abs(DSS.sumn).quantile(q)), drop=True)
pb.plot.scatter(x='longitude', y='latitude')
pb = DSS.where((abs(DSS.sume)<abs(DSS.sume).quantile(1-q))| (abs(DSS.sumn)<abs(DSS.sumn).quantile(1-q)), drop=True)
pb.plot.scatter(x='longitude', y='latitude')
pb = DSD.where((abs(DSD.sume)>abs(DSD.sume).quantile(q))| (abs(DSD.sumn)>abs(DSD.sumn).quantile(q)), drop=True)
pb.plot.scatter(x='longitude', y='latitude')
pb = DSD.where((abs(DSD.sume)<abs(DSD.sume).quantile(1-q))| (abs(DSD.sumn)<abs(DSD.sumn).quantile(1-q)), drop=True)
pb.plot.scatter(x='longitude', y='latitude')
# Out:
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /Users/mdemol/opt/anaconda3/envs/equinox/lib/python3.10/site-packages/xarray/backends/plugins.py:159: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
