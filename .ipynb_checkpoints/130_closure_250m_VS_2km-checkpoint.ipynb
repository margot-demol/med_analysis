# %% [markdown]
# ____
# # Colocalization dataset
# - put all variables for reconstruction in the same file

# %%
import numpy as np
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt

import os
from glob import glob

from cstes import swot_dir, drifters_dir, get_proj, lonlat2xy, zarr_dir, surface_drifters, depth_drifters, depth_100, depth_50, images_dir, U2
from swot import browse_swot_250, add_mask_inside_swot, build_swath_polygon
from diagnosis import dataset_coloc_combs, DRIFTER, ALTI, WD

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.geodesic as cgeo
crs = ccrs.PlateCarree()

import cartopy.geodesic as geod
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import pyproj
from pyproj import Geod

from rasterio.transform import Affine

import pynsitu as pyn

from diagnosis import synthetic_figure
from cstes import U2, c0
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="eb8ca461-f09e-47cc-8f98-2a30927d501e" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a3fc23ef-ed07-432a-b5aa-9ca28f8079d6":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"da02894454d34ebb9247ed9a67280e3f","client_comm_id":"d8cfe6fe91d643d583c12a7d3c7398d3"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"a3fc23ef-ed07-432a-b5aa-9ca28f8079d6","roots":{"p1002":"eb8ca461-f09e-47cc-8f98-2a30927d501e"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Warning: could not import utide
# Warning: could not import pyTMD

# %%
# Out:
# '/Users/mdemol/ownCloud/PhD/images/med_images'

# %% [markdown]
# _______
# # Data

# %%
DRIFTER.keys(), ALTI.keys(), WD.keys()
# wd_depth = '0' or '15'
# ggd_var = 'etaf', 'etac', 'adtf', 'adtc', 'fromduacsv'
# Out:
# (dict_keys(['nofilter', '0.5cpd', '1.5cpd', '2.5cpd', '3cpd']),
#  dict_keys(['swot250naive', 'swot250gauss1e3', 'swot250gauss2e3', 'swot250gauss3e3', 'swot250gauss4e3', 'swot250gauss5e3', 'swot2kmnaive', 'swot2kmgauss1e3', 'swot2kmgauss2e3', 'swot2kmgauss3e3', 'swot2kmgauss4e3', 'swot2kmgauss5e3', 'swot2kmgauss1e4']),
#  dict_keys(['era5']))

# %%
def compute_mean_square(ds):
    var = ['acc', 'cor', 'ggd', 'wd','sum']
    VAR = ['ACC', 'COR', 'GGD', 'WD', 'S']
    dss = (ds[[v+'n' for v in var] + [v+'e' for v in var]]**2).mean(dim='row_number').rename({var[i]+'n' : VAR[i]+'n' for i in range(5)}).rename({var[i]+'e' : VAR[i]+'e' for i in range(5)})
    dss['sigmae'] = dss.ACCe + dss.CORe + dss.GGDe + dss.WDe
    dss['sigman'] = dss.ACCn + dss.CORn + dss.GGDn + dss.WDn
    dss['nb_coloc'] = len(ds.row_number)
    #Balanced and error
    for direction in ['e', 'n']:
        for v in ['acc', 'cor', 'ggd', 'wd'] : 
                dss['B'+direction+'_'+v] = -((ds[v+direction]*ds['exc'+direction+'_'+v])).mean(dim='row_number')
                dss['E'+direction+'_'+v] = ((ds[v+direction]*ds['sum'+direction])).mean(dim='row_number')
    #pairs contributions
    for v in [v for v in ds if 'prod' in v]:
        dss[v.replace('prod', 'X')]=-2*ds[v].mean(dim='row_number')
    return dss

# %% [markdown]
# __________________
# ## Sensitivity to SWOT-250m filtering

# %%
comb_list = [dict(drifter_key='nofilter', alti_key = 'swot250naive', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='nofilter', alti_key = 'swot250gauss1e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='nofilter', alti_key = 'swot250gauss2e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='nofilter', alti_key = 'swot250gauss3e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='nofilter', alti_key = 'swot250gauss4e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'),
             dict(drifter_key='nofilter', alti_key = 'swot250gauss5e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15')]

#DS = dataset_coloc_combs(comb_list, nearest =True)
#DSS = DS.where(DS.depth==0, drop=True)
#DSD = DS.where(DS.depth==15, drop=True)
#ds = compute_mean_square(DSD)/U2
df = ds.to_dataframe()
for c in ds.id_comb.values :
    fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False)
    synthetic_figure(df.loc[c], axs[0], dir='e')
    synthetic_figure(df.loc[c], axs[1], dir='n')
    fig.suptitle(c)
    fig.tight_layout()
    fig.savefig(os.path.join(images_dir, 'closure_figs', c + '.png'))
# Out:
# 29.088968405474617
# 29.38888943077225
# 124.23287351916272
# 125.29699968816169
# 13.58337441682201
# 13.746958700834519
# 66.69191534701731
# 67.26937442316935
# 10.504366780296428
# 10.616492674578868
# 20.395941858573952
# 20.502025837402766
# 8.264121719580015
# 8.36839759063133
# 11.701667775554716
# 11.744009758738502
# 5.819724452832797
# 5.913062184047927
# 8.268251749864588
# 8.258985678410225
# 5.000476803797131
# 5.045801904698143
# 6.701302203586469
# 6.681076052168828

# %%
var= ['acc', 'cor', 'ggd', 'wd']
ds['id_comb']= ['Naive', '1 ', '2', '3', '4', '5']

fig, axs = plt.subplots(5,2, sharex=True, figsize = (10, 10))
axs =axs.flatten()

ax=axs[0]
ds.Se.plot(ax=ax)
ds.Sn.plot(ax=ax)
ax.set_ylabel(rf'$S$ [$\gamma^2$]')

ax=axs[1]
ds.GGDe.plot(ax=ax)
ds.GGDn.plot(ax=ax)
ax.set_ylabel(rf'$GGD$ [$\gamma^2$]')

for i in range(2, 6):
    v = var[i-2]
    ax=axs[i]
    ds['Be_'+v].plot(ax=ax, c=c0[v])
    ds['Bn_'+v].plot(ax=ax, c=c0[v], ls='--')
    ax.set_ylabel(rf'$\beta_{v}$ [$\gamma^2$]')

for i in range(6, 10):
    v = var[i-6]
    ax=axs[i]
    ds['Ee_'+v].plot(ax=ax, c=c0[v])
    ds['En_'+v].plot(ax=ax, c=c0[v], ls='--')
    ax.set_ylabel(rf'$\epsilon_{v}$ [$\gamma^2$]')
    
for ax in axs :
    ax.set_xlabel('Length of the Gaussian filter \n applied on SWOT at 250 [km]')
    ax.grid()
fig.suptitle('nofilter__swot250****_etaf__15era5')
fig.tight_layout()

# %% [markdown]
# ______
# # Sensitivity of SWOT 250m 2e3 to the drifter filter

# %%
comb_list = [dict(drifter_key='nofilter', alti_key = 'swot250gauss2e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='0.5cpd', alti_key = 'swot250gauss2e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='1.5cpd', alti_key = 'swot250gauss2e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='2.5cpd', alti_key = 'swot250gauss2e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='3cpd', alti_key = 'swot250gauss2e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'),
             ]

DS = dataset_coloc_combs(comb_list, nearest =True)
DSS = DS.where(DS.depth==0, drop=True)
DSD = DS.where(DS.depth==15, drop=True)
ds = compute_mean_square(DSD)/U2
df = ds.to_dataframe()
for c in ds.id_comb.values :
    fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False)
    synthetic_figure(df.loc[c], axs[0], dir='e')
    synthetic_figure(df.loc[c], axs[1], dir='n')
    fig.suptitle(c)
    fig.tight_layout()
# Out:
# nofilter__swot250gauss2e3_etaf__15era5
# 0.5cpd__swot250gauss2e3_etaf__15era5
# 1.5cpd__swot250gauss2e3_etaf__15era5
# 2.5cpd__swot250gauss2e3_etaf__15era5
# 3cpd__swot250gauss2e3_etaf__15era5
# 10.504366780296428
# 10.616492674578868
# 20.395941858573952
# 20.502025837402766
# 8.439533652300268
# 8.469751818030105
# 18.072927265131035
# 18.162732888564936
# 9.875120239536317
# 9.937523211082134
# 19.699128235887084
# 19.83841492278008
# 10.198186121442285
# 10.285578422842784
# 20.159600558782245
# 20.29088614812073
# 10.26994278890704
# 10.352976556187402
# 20.263677213695235
# 20.38940368238994

# %%
var= ['acc', 'cor', 'ggd', 'wd']
if not 'nofilter' in ds.id_comb :
    ds['id_comb']= ['nofilter', '0.5 ', '1.5', '2.5', '3']
    ds = ds.sortby('id_comb', ['0.5 ', '1.5', '2.5', '3', 'no_filter'])

fig, axs = plt.subplots(5,2, sharex=True, figsize = (10, 10))
axs =axs.flatten()

ax=axs[0]
ds.Se.plot(ax=ax)
ds.Sn.plot(ax=ax)
ax.set_ylabel(rf'$S$ [$\gamma^2$]')

ax=axs[1]
ds.ACCe.plot(ax=ax)
ds.ACCn.plot(ax=ax)
ax.set_ylabel(rf'$ACC$ [$\gamma^2$]')

for i in range(2, 6):
    v = var[i-2]
    ax=axs[i]
    ds['Be_'+v].plot(ax=ax, c=c0[v])
    ds['Bn_'+v].plot(ax=ax, c=c0[v], ls='--')
    ax.set_ylabel(rf'$\beta_{v}$ [$\gamma^2$]')

for i in range(6, 10):
    v = var[i-6]
    ax=axs[i]
    ds['Ee_'+v].plot(ax=ax, c=c0[v])
    ds['En_'+v].plot(ax=ax, c=c0[v], ls='--')
    ax.set_ylabel(rf'$\epsilon_{v}$ [$\gamma^2$]')
    
for ax in axs :
    ax.set_xlabel('Drifters filter [cpd]')
    ax.grid()
fig.suptitle('***__swot250m_etaf__15era5')
fig.tight_layout()

# %% [markdown]
# ________________
# # SWOT 2km filter on alti ?

# %%
comb_list = [dict(drifter_key='nofilter', alti_key = 'swot2kmnaive', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='nofilter', alti_key = 'swot2kmgauss1e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='nofilter', alti_key = 'swot2kmgauss2e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='nofilter', alti_key = 'swot2kmgauss3e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='nofilter', alti_key = 'swot2kmgauss4e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15'),
             dict(drifter_key='nofilter', alti_key = 'swot2kmgauss5e3', wd_key = 'era5', ggd_var='etaf', wd_depth='15')]

DS = dataset_coloc_combs(comb_list, nearest =True)
DSS = DS.where(DS.depth==0, drop=True)
DSD = DS.where(DS.depth==15, drop=True)
ds = compute_mean_square(DSD)/U2

df = ds.to_dataframe()
for c in ds.id_comb.values :
    fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False)
    synthetic_figure(df.loc[c], axs[0], dir='e')
    synthetic_figure(df.loc[c], axs[1], dir='n')
    fig.suptitle(c)
    fig.tight_layout()
# Out:
# nofilter__swot2kmnaive_etaf__15era5
# nofilter__swot2kmgauss1e3_etaf__15era5
# nofilter__swot2kmgauss2e3_etaf__15era5
# nofilter__swot2kmgauss3e3_etaf__15era5
# nofilter__swot2kmgauss4e3_etaf__15era5
# nofilter__swot2kmgauss5e3_etaf__15era5
# 4.703765021005737
# 4.723696715174654
# 5.802999586533861
# 5.654425985020742
# 4.388587115720522
# 4.398569724347815
# 5.374960146503165
# 5.260059746922825
# 4.655097811353584
# 4.687060766041162
# 5.689504920990153
# 5.5872250584001355
# 4.601984367109382
# 4.620242166172846
# 5.534219257174819
# 5.410627863164063
# 4.526844244755744
# 4.491542274181187
# 5.430207507164661
# 5.282389496167362
# 4.473726829162955
# 4.483298607683137
# 5.335105507454811
# 5.227017720161194

# %%
var= ['acc', 'cor', 'ggd', 'wd']
ds['id_comb']= ['Naive', '1 ', '2', '3', '4', '5']

fig, axs = plt.subplots(5,2, sharex=True, figsize = (10, 10))
axs =axs.flatten()

ax=axs[0]
ds.Se.plot(ax=ax)
ds.Sn.plot(ax=ax)
ax.set_ylabel(rf'$S$ [$\gamma^2$]')

ax=axs[1]
ds.GGDe.plot(ax=ax)
ds.GGDn.plot(ax=ax)
ax.set_ylabel(rf'$GGD$ [$\gamma^2$]')

for i in range(2, 6):
    v = var[i-2]
    ax=axs[i]
    ds['Be_'+v].plot(ax=ax, c=c0[v])
    ds['Bn_'+v].plot(ax=ax, c=c0[v], ls='--')
    ax.set_ylabel(rf'$\beta_{v}$ [$\gamma^2$]')

for i in range(6, 10):
    v = var[i-6]
    ax=axs[i]
    ds['Ee_'+v].plot(ax=ax, c=c0[v])
    ds['En_'+v].plot(ax=ax, c=c0[v], ls='--')
    ax.set_ylabel(rf'$\epsilon_{v}$ [$\gamma^2$]')
    
for ax in axs :
    ax.set_xlabel('Length of the Gaussian filter \n applied on SWOT at 2km [km]')
    ax.grid()
fig.suptitle('nofilter__swot2km****_etaf__15era5')
fig.tight_layout()

# %% [markdown]
# ________________
# # SWOT 2km filter on alti ?

# %%
comb_list = [dict(drifter_key='nofilter', alti_key = 'swot2kmnaive', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='0.5cpd', alti_key = 'swot2kmnaive', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='1.5cpd', alti_key = 'swot2kmnaive', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='2.5cpd', alti_key = 'swot2kmnaive', wd_key = 'era5', ggd_var='etaf', wd_depth='15'), 
             dict(drifter_key='3cpd', alti_key = 'swot2kmnaive', wd_key = 'era5', ggd_var='etaf', wd_depth='15'),
             ]

DS = dataset_coloc_combs(comb_list, nearest =True)
DSS = DS.where(DS.depth==0, drop=True)
DSD = DS.where(DS.depth==15, drop=True)
ds = compute_mean_square(DSD)/U2
# Out:
# nofilter__swot2kmnaive_etaf__15era5
# 0.5cpd__swot2kmnaive_etaf__15era5
# 1.5cpd__swot2kmnaive_etaf__15era5
# 2.5cpd__swot2kmnaive_etaf__15era5
# 3cpd__swot2kmnaive_etaf__15era5

# %%
var= ['acc', 'cor', 'ggd', 'wd']
if not 'nofilter' in ds.id_comb :
    ds['id_comb']= ['nofilter', '0.5 ', '1.5', '2.5', '3']
    ds = ds.sortby('id_comb', ['0.5 ', '1.5', '2.5', '3', 'no_filter'])

fig, axs = plt.subplots(5,2, sharex=True, figsize = (10, 10))
axs =axs.flatten()

ax=axs[0]
ds.Se.plot(ax=ax)
ds.Sn.plot(ax=ax)
ax.set_ylabel(rf'$S$ [$\gamma^2$]')

ax=axs[1]
ds.ACCe.plot(ax=ax)
ds.ACCn.plot(ax=ax)
ax.set_ylabel(rf'$ACC$ [$\gamma^2$]')

for i in range(2, 6):
    v = var[i-2]
    ax=axs[i]
    ds['Be_'+v].plot(ax=ax, c=c0[v])
    ds['Bn_'+v].plot(ax=ax, c=c0[v], ls='--')
    ax.set_ylabel(rf'$\beta_{v}$ [$\gamma^2$]')

for i in range(6, 10):
    v = var[i-6]
    ax=axs[i]
    ds['Ee_'+v].plot(ax=ax, c=c0[v])
    ds['En_'+v].plot(ax=ax, c=c0[v], ls='--')
    ax.set_ylabel(rf'$\epsilon_{v}$ [$\gamma^2$]')
    
for ax in axs :
    ax.set_xlabel('Drifters filter [cpd]')
    ax.grid()
fig.suptitle('***__swot2km_etaf__15era5')
fig.tight_layout()

# %%
df = ds.to_dataframe()
for c in ds.id_comb.values :
    fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False)
    synthetic_figure(df.loc[c], axs[0], dir='e', xlim=6 )
    synthetic_figure(df.loc[c], axs[1], dir='n', xlim=6)
    fig.suptitle(c)
    fig.tight_layout()
# Out:
# 2.638931893009576
# 2.6534120861986814
# 3.479984993090941
# 3.3383039720447196
# 4.074518480245626
# 4.087106378187613
# 5.1061859638469915
# 4.9758910904128175
# 4.397584362151594
# 4.431768114615504
# 5.566658286742149
# 5.4141134177238674
# 4.469341029616347
# 4.507370615805606
# 5.670734941655143
# 5.519052271666888
# 4.703765021005737
# 4.736659064964597
# 5.802999586533861
# 5.656395989155403

# %% [markdown]
# # Visualization

# %%
ds__= DS.sel(id_comb = 'etaf_swot250gauss1e3__15era5').isel(row_number=slice(20,40))
fig, ax = plt.subplots()
s = 3e-4
ds__.plot.quiver('longitude', 'latitude', 'acce', 'accn', color =c0['acc'], pivot='tail', scale=s )
ds__.plot.quiver('longitude', 'latitude', 'core', 'corn', color =c0['cor'],pivot='tail', scale=s )
ds__.plot.quiver('longitude', 'latitude', 'ggde', 'ggdn', color =c0['ggd'],pivot='tail', scale=s )
ds__.plot.quiver('longitude', 'latitude', 'wde', 'wdn', color =c0['wd'],pivot='tail', scale=s)
ds__.plot.quiver('longitude', 'latitude', 'sume', 'sumn', color ='k', pivot='tail', scale=s )

# %% [markdown]
# # MS

# %%
def compute_mean_square(ds):
    var = ['acc', 'cor', 'ggd', 'wd','sum']
    VAR = ['ACC', 'COR', 'GGD', 'WD', 'S']
    dss = (ds[[v+'n' for v in var] + [v+'e' for v in var]]**2).mean(dim='row_number').rename({var[i]+'n' : VAR[i]+'n' for i in range(5)}).rename({var[i]+'e' : VAR[i]+'e' for i in range(5)})
    dss['sigmae'] = dss.ACCe + dss.CORe + dss.GGDe + dss.WDe
    dss['sigman'] = dss.ACCn + dss.CORn + dss.GGDn + dss.WDn
    dss['nb_coloc'] = len(ds.row_number)
    #Balanced and error
    for direction in ['e', 'n']:
        for v in ['acc', 'cor', 'ggd', 'wd'] : 
                dss['B'+direction+'_'+v] = -((ds[v+direction]*ds['exc'+direction+'_'+v])).mean(dim='row_number')
                dss['E'+direction+'_'+v] = ((ds[v+direction]*ds['sum'+direction])).mean(dim='row_number')
    #pairs contributions
    for v in [v for v in ds if 'prod' in v]:
        dss[v.replace('prod', 'X')]=-2*ds[v].mean(dim='row_number')
    return dss

dsm = compute_mean_square(DS)/U2
dsms =compute_mean_square(DSS)/U2
dsmd =compute_mean_square(DSD)/U2

# %%
dsmd
# Out:
# <xarray.Dataset> Size: 41kB
# Dimensions:     (id_comb: 72)
# Coordinates:
#   * id_comb     (id_comb) <U63 18kB 'duacs_ssha_karin_2_filtered_swot250naive...
# Data variables: (12/41)
#     ACCn        (id_comb) float64 576B 1.225 1.225 1.225 ... 1.225 1.225 1.225
#     CORn        (id_comb) float64 576B 3.407 3.407 3.407 ... 3.407 3.407 3.407
#     GGDn        (id_comb) float64 576B 2.776 2.776 824.7 ... 1.575 1.579 1.579
#     WDn         (id_comb) float64 576B 0.07119 0.004927 ... 0.07119 0.004927
#     Sn          (id_comb) float64 576B 2.622 2.55 827.8 ... 1.039 1.082 1.046
#     ACCe        (id_comb) float64 576B 1.165 1.165 1.165 ... 1.165 1.165 1.165
#     ...          ...
#     Xn_acc_cor  (id_comb) float64 576B 2.465 2.465 2.465 ... 2.465 2.465 2.465
#     Xn_acc_ggd  (id_comb) float64 576B -0.1489 -0.1489 4.836 ... -0.4505 -0.4505
#     Xn_acc_wd   (id_comb) float64 576B -0.05074 -0.009325 ... -0.05074 -0.009325
#     Xn_cor_ggd  (id_comb) float64 576B 2.522 2.522 -5.8 ... 3.101 3.106 3.106
#     Xn_cor_wd   (id_comb) float64 576B 0.1167 0.04549 0.1167 ... 0.1167 0.04549
#     Xn_ggd_wd   (id_comb) float64 576B -0.04759 -0.01173 ... 0.01253 0.01179

# %%
df = dsmd.to_dataframe()
df
# Out:
#                                                         ACCn      CORn  \
# id_comb
# duacs_ssha_karin_2_filtered_swot250naive__0era5     1.224501  3.407025
# duacs_ssha_karin_2_filtered_swot250naive__15era5    1.224501  3.407025
# duacs_ssha_karin_2_calibrated_swot250naive__0era5   1.224501  3.407025
# duacs_ssha_karin_2_calibrated_swot250naive__15era5  1.224501  3.407025
# cvl_mean_dynamic_topography_cnes_cls_22_swot250...  1.224501  3.407025
# ...                                                      ...       ...
# adtf_swot250gauss5e3__15era5                        1.224501  3.407025
# etac_swot250gauss5e3__0era5                         1.224501  3.407025
# etac_swot250gauss5e3__15era5                        1.224501  3.407025
# adtc_swot250gauss5e3__0era5                         1.224501  3.407025
# adtc_swot250gauss5e3__15era5                        1.224501  3.407025
#
#                                                           GGDn       WDn  \
# id_comb
# duacs_ssha_karin_2_filtered_swot250naive__0era5       2.776059  0.071192
# duacs_ssha_karin_2_filtered_swot250naive__15era5      2.776059  0.004927
# duacs_ssha_karin_2_calibrated_swot250naive__0era5   824.678179  0.071192
# duacs_ssha_karin_2_calibrated_swot250naive__15era5  824.678179  0.004927
# cvl_mean_dynamic_topography_cnes_cls_22_swot250...    0.477574  0.071192
# ...                                                        ...       ...
# adtf_swot250gauss5e3__15era5                          1.567269  0.004927
# etac_swot250gauss5e3__0era5                           1.574759  0.071192
# etac_swot250gauss5e3__15era5                          1.574759  0.004927
# adtc_swot250gauss5e3__0era5                           1.578683  0.071192
# adtc_swot250gauss5e3__15era5                          1.578683  0.004927
#
#                                                             Sn     ACCe  \
# id_comb
# duacs_ssha_karin_2_filtered_swot250naive__0era5       2.622115  1.16454
# duacs_ssha_karin_2_filtered_swot250naive__15era5      2.549834  1.16454
# duacs_ssha_karin_2_calibrated_swot250naive__0era5   827.809722  1.16454
# duacs_ssha_karin_2_calibrated_swot250naive__15era5  827.705497  1.16454
# cvl_mean_dynamic_topography_cnes_cls_22_swot250...    1.888846  1.16454
# ...                                                        ...      ...
# adtf_swot250gauss5e3__15era5                          1.034683  1.16454
# etac_swot250gauss5e3__0era5                           1.075867  1.16454
# etac_swot250gauss5e3__15era5                          1.039346  1.16454
# adtc_swot250gauss5e3__0era5                           1.081953  1.16454
# adtc_swot250gauss5e3__15era5                          1.046264  1.16454
#
#                                                         CORe         GGDe  \
# id_comb
# duacs_ssha_karin_2_filtered_swot250naive__0era5     2.260188     2.280898
# duacs_ssha_karin_2_filtered_swot250naive__15era5    2.260188     2.280898
# duacs_ssha_karin_2_calibrated_swot250naive__0era5   2.260188  1089.532387
# duacs_ssha_karin_2_calibrated_swot250naive__15era5  2.260188  1089.532387
# cvl_mean_dynamic_topography_cnes_cls_22_swot250...  2.260188     0.133145
# ...                                                      ...          ...
# adtf_swot250gauss5e3__15era5                        2.260188     1.159635
# etac_swot250gauss5e3__0era5                         2.260188     1.199693
# etac_swot250gauss5e3__15era5                        2.260188     1.199693
# adtc_swot250gauss5e3__0era5                         2.260188     1.188226
# adtc_swot250gauss5e3__15era5                        2.260188     1.188226
#
#                                                          WDe           Se  \
# id_comb
# duacs_ssha_karin_2_filtered_swot250naive__0era5     0.604646     2.514804
# duacs_ssha_karin_2_filtered_swot250naive__15era5    0.037313     2.173075
# duacs_ssha_karin_2_calibrated_swot250naive__0era5   0.604646  1094.491923
# duacs_ssha_karin_2_calibrated_swot250naive__15era5  0.037313  1086.422375
# cvl_mean_dynamic_topography_cnes_cls_22_swot250...  0.604646     1.712630
# ...                                                      ...          ...
# adtf_swot250gauss5e3__15era5                        0.037313     1.005290
# etac_swot250gauss5e3__0era5                         0.604646     1.346527
# etac_swot250gauss5e3__15era5                        0.037313     1.055888
# adtc_swot250gauss5e3__0era5                         0.604646     1.335484
# adtc_swot250gauss5e3__15era5                        0.037313     1.054522
#
#                                                     ...  Xe_acc_wd  \
# id_comb                                             ...
# duacs_ssha_karin_2_filtered_swot250naive__0era5     ...  -0.157009
# duacs_ssha_karin_2_filtered_swot250naive__15era5    ...  -0.034621
# duacs_ssha_karin_2_calibrated_swot250naive__0era5   ...  -0.157009
# duacs_ssha_karin_2_calibrated_swot250naive__15era5  ...  -0.034621
# cvl_mean_dynamic_topography_cnes_cls_22_swot250...  ...  -0.157009
# ...                                                 ...        ...
# adtf_swot250gauss5e3__15era5                        ...  -0.034621
# etac_swot250gauss5e3__0era5                         ...  -0.157009
# etac_swot250gauss5e3__15era5                        ...  -0.034621
# adtc_swot250gauss5e3__0era5                         ...  -0.157009
# adtc_swot250gauss5e3__15era5                        ...  -0.034621
#
#                                                     Xe_cor_ggd  Xe_cor_wd  \
# id_comb
# duacs_ssha_karin_2_filtered_swot250naive__0era5       1.608810   0.596966
# duacs_ssha_karin_2_filtered_swot250naive__15era5      1.608810   0.145420
# duacs_ssha_karin_2_calibrated_swot250naive__0era5     8.911500   0.596966
# duacs_ssha_karin_2_calibrated_swot250naive__15era5    8.911500   0.145420
# cvl_mean_dynamic_topography_cnes_cls_22_swot250...    0.226948   0.596966
# ...                                                        ...        ...
# adtf_swot250gauss5e3__15era5                          1.749387   0.145420
# etac_swot250gauss5e3__0era5                           1.751888   0.596966
# etac_swot250gauss5e3__15era5                          1.751888   0.145420
# adtc_swot250gauss5e3__0era5                           1.737644   0.596966
# adtc_swot250gauss5e3__15era5                          1.737644   0.145420
#
#                                                     Xe_ggd_wd  Xn_acc_cor  \
# id_comb
# duacs_ssha_karin_2_filtered_swot250naive__0era5     -0.136626      2.4649
# duacs_ssha_karin_2_filtered_swot250naive__15era5    -0.033073      2.4649
# duacs_ssha_karin_2_calibrated_swot250naive__0era5  -10.307581      2.4649
# duacs_ssha_karin_2_calibrated_swot250naive__15era5  -2.476208      2.4649
# cvl_mean_dynamic_topography_cnes_cls_22_swot250...  -0.039375      2.4649
# ...                                                       ...         ...
# adtf_swot250gauss5e3__15era5                        -0.021895      2.4649
# etac_swot250gauss5e3__0era5                         -0.070692      2.4649
# etac_swot250gauss5e3__15era5                        -0.018228      2.4649
# adtc_swot250gauss5e3__0era5                         -0.058051      2.4649
# adtc_swot250gauss5e3__15era5                        -0.015263      2.4649
#
#                                                     Xn_acc_ggd  Xn_acc_wd  \
# id_comb
# duacs_ssha_karin_2_filtered_swot250naive__0era5      -0.148883  -0.050741
# duacs_ssha_karin_2_filtered_swot250naive__15era5     -0.148883  -0.009325
# duacs_ssha_karin_2_calibrated_swot250naive__0era5     4.836260  -0.050741
# duacs_ssha_karin_2_calibrated_swot250naive__15era5    4.836260  -0.009325
# cvl_mean_dynamic_topography_cnes_cls_22_swot250...   -0.193446  -0.050741
# ...                                                        ...        ...
# adtf_swot250gauss5e3__15era5                         -0.434185  -0.009325
# etac_swot250gauss5e3__0era5                          -0.442277  -0.050741
# etac_swot250gauss5e3__15era5                         -0.442277  -0.009325
# adtc_swot250gauss5e3__0era5                          -0.450478  -0.050741
# adtc_swot250gauss5e3__15era5                         -0.450478  -0.009325
#
#                                                     Xn_cor_ggd  Xn_cor_wd  \
# id_comb
# duacs_ssha_karin_2_filtered_swot250naive__0era5       2.522231   0.116748
# duacs_ssha_karin_2_filtered_swot250naive__15era5      2.522231   0.045488
# duacs_ssha_karin_2_calibrated_swot250naive__0era5    -5.799990   0.116748
# duacs_ssha_karin_2_calibrated_swot250naive__15era5   -5.799990   0.045488
# cvl_mean_dynamic_topography_cnes_cls_22_swot250...    0.937271   0.116748
# ...                                                        ...        ...
# adtf_swot250gauss5e3__15era5                          3.090945   0.045488
# etac_swot250gauss5e3__0era5                           3.101268   0.116748
# etac_swot250gauss5e3__15era5                          3.101268   0.045488
# adtc_swot250gauss5e3__0era5                           3.106492   0.116748
# adtc_swot250gauss5e3__15era5                          3.106492   0.045488
#
#                                                     Xn_ggd_wd
# id_comb
# duacs_ssha_karin_2_filtered_swot250naive__0era5     -0.047592
# duacs_ssha_karin_2_filtered_swot250naive__15era5    -0.011733
# duacs_ssha_karin_2_calibrated_swot250naive__0era5    0.003999
# duacs_ssha_karin_2_calibrated_swot250naive__15era5   0.071802
# cvl_mean_dynamic_topography_cnes_cls_22_swot250...   0.016715
# ...                                                       ...
# adtf_swot250gauss5e3__15era5                         0.011218
# etac_swot250gauss5e3__0era5                          0.011712
# etac_swot250gauss5e3__15era5                         0.011812
# adtc_swot250gauss5e3__0era5                          0.012528
# adtc_swot250gauss5e3__15era5                         0.011795
#
# [72 rows x 41 columns]

# %%
comb = [v for v in dsm.id_comb.values if 'adt' in v] + [v for v in dsm.id_comb.values if 'eta' in v] + [v for v in dsm.id_comb.values if 'from' in v]
comb0 = [v for v in comb if '0era' in v]
comb15 = [v for v in comb if '15era' in v]
comb15
# Out:
# ['adtf_swot250naive__15era5',
#  'adtc_swot250naive__15era5',
#  'adtf_swot250gauss1e3__15era5',
#  'adtc_swot250gauss1e3__15era5',
#  'adtf_swot250gauss2e3__15era5',
#  'adtc_swot250gauss2e3__15era5',
#  'adtf_swot250gauss5e3__15era5',
#  'adtc_swot250gauss5e3__15era5',
#  'etaf_swot250naive__15era5',
#  'etac_swot250naive__15era5',
#  'etaf_swot250gauss1e3__15era5',
#  'etac_swot250gauss1e3__15era5',
#  'etaf_swot250gauss2e3__15era5',
#  'etac_swot250gauss2e3__15era5',
#  'etaf_swot250gauss5e3__15era5',
#  'etac_swot250gauss5e3__15era5',
#  'fromduacsv_swot250naive__15era5',
#  'fromduacsv_swot250gauss1e3__15era5',
#  'fromduacsv_swot250gauss2e3__15era5',
#  'fromduacsv_swot250gauss5e3__15era5']

# %% [markdown]
# # Swot filtrage

# %%
c = 'etaf_swot250naive__15era5'
fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False,)
synthetic_figure(df.loc[c], axs[0], dir='e')
synthetic_figure(df.loc[c], axs[1], dir='n')
fig.suptitle(c)
fig.tight_layout()

c = 'etaf_swot250gauss1e3__15era5'
fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False,)
synthetic_figure(df.loc[c], axs[0], dir='e')
synthetic_figure(df.loc[c], axs[1], dir='n')
fig.suptitle(c)
fig.tight_layout()

c = 'etaf_swot250gauss2e3__15era5'
fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False,)
synthetic_figure(df.loc[c], axs[0], dir='e')
synthetic_figure(df.loc[c], axs[1], dir='n')
fig.suptitle(c)
fig.tight_layout()

c = 'etaf_swot250gauss5e3__15era5'
fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False,)
synthetic_figure(df.loc[c], axs[0], dir='e')
synthetic_figure(df.loc[c], axs[1], dir='n')
fig.suptitle(c)
fig.tight_layout()
# Out:
# 5.827464383027202
# 5.968887558142416
# 7.815631173954805
# 7.8968408696419905
# 5.585850209282852
# 5.719890646854031
# 7.370497780005536
# 7.445348371633019
# 5.585850209282852
# 5.719890646854031
# 7.370497780005536
# 7.445348371633019
# 4.633770664425903
# 4.73958974547408
# 6.202247339303583
# 6.2623602785133

# %% [markdown]
# # Etaf, etac

# %%
c = 'etaf_swot250gauss5e3__15era5'
fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False,)
synthetic_figure(df.loc[c], axs[0], dir='e')
synthetic_figure(df.loc[c], axs[1], dir='n')
fig.suptitle(c)
fig.tight_layout()

c = 'etac_swot250gauss5e3__15era5'
fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False,)
synthetic_figure(df.loc[c], axs[0], dir='e')
synthetic_figure(df.loc[c], axs[1], dir='n')
fig.suptitle(c)
fig.tight_layout()
# Out:
# 4.633770664425903
# 4.73958974547408
# 6.202247339303583
# 6.2623602785133
# 4.661734564164215
# 4.761201244460434
# 6.2112122401862395
# 6.2708378004512415

# %%
c = 'etaf_swot250gauss5e3__15era5'
fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False,)
synthetic_figure(df.loc[c], axs[0], dir='e')
synthetic_figure(df.loc[c], axs[1], dir='n')
fig.suptitle(c)
fig.tight_layout()

c = 'adtf_swot250gauss5e3__15era5'
fig, axs = plt.subplots(nrows=1,ncols=2,figsize=(20,5), frameon=False,)
synthetic_figure(df.loc[c], axs[0], dir='e')
synthetic_figure(df.loc[c], axs[1], dir='n')
fig.suptitle(c)
fig.tight_layout()
# Out:
# 4.633770664425903
# 4.73958974547408
# 6.202247339303583
# 6.2623602785133
# 4.621676791866464
# 4.7244103926240335
# 6.203722741149835
# 6.263867718202855
