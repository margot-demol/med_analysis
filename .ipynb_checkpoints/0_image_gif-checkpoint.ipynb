# %%
import numpy as np
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt

import os
from glob import glob

from medlib.cstes import swot_dir, drifters_dir
from medlib.swot import browse_swot, add_mask_inside_swot, build_swath_polygon

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.geodesic as cgeo
crs = ccrs.PlateCarree()
# Out:
# /home1/datahome/mdemol/.miniconda3/envs/histenv2/lib/python3.9/site-packages/dask/config.py:742: FutureWarning: Dask configuration key 'distributed.scheduler.transition-log-length' has been deprecated; please use 'distributed.admin.low-level-log-length' instead
#   warnings.warn(
# /home1/datahome/mdemol/.miniconda3/envs/histenv2/lib/python3.9/site-packages/dask/config.py:742: FutureWarning: Dask configuration key 'distributed.comm.recent-messages-log-length' has been deprecated; please use 'distributed.admin.low-level-log-length' instead
#   warnings.warn(

# %%
dfs = browse_swot().reset_index()
dfs
# Out:
#            day  pass_number  cycle_number  \
# 0   2023-04-01            3           478
# 1   2023-04-02            3           479
# 2   2023-04-03            3           480
# 3   2023-04-04            3           481
# 4   2023-04-05            3           482
# ..         ...          ...           ...
# 182 2023-07-05           16           573
# 183 2023-07-06           16           574
# 184 2023-07-07           16           575
# 185 2023-07-08           16           576
# 186 2023-07-09           16           577
#
#                                                   file  \
# 0    /home/datawork-lops-osi/aponte/swot/cswot/swot...
# 1    /home/datawork-lops-osi/aponte/swot/cswot/swot...
# 2    /home/datawork-lops-osi/aponte/swot/cswot/swot...
# 3    /home/datawork-lops-osi/aponte/swot/cswot/swot...
# 4    /home/datawork-lops-osi/aponte/swot/cswot/swot...
# ..                                                 ...
# 182  /home/datawork-lops-osi/aponte/swot/cswot/swot...
# 183  /home/datawork-lops-osi/aponte/swot/cswot/swot...
# 184  /home/datawork-lops-osi/aponte/swot/cswot/swot...
# 185  /home/datawork-lops-osi/aponte/swot/cswot/swot...
# 186  /home/datawork-lops-osi/aponte/swot/cswot/swot...
#
#                              time
# 0   2023-04-01 23:42:32.696536000
# 1   2023-04-02 23:33:10.425673088
# 2   2023-04-03 23:23:48.189185728
# 3   2023-04-04 23:14:25.904031360
# 4   2023-04-05 23:05:03.656492928
# ..                            ...
# 182 2023-07-05 19:33:50.331633280
# 183 2023-07-06 19:24:28.273369600
# 184 2023-07-07 19:15:06.145279168
# 185 2023-07-08 19:05:44.003893184
# 186 2023-07-09 18:56:21.868455616
#
# [187 rows x 5 columns]

# %% [markdown]
# # One image

# %%
# SWOT
df3 = dfs.where(dfs.pass_number==int(3)).dropna()
dss = xr.open_dataset(df3.iloc[0].file)
dss['eta'] = dss.cvl_mean_dynamic_topography_cnes_cls_22 + dss.cvl_ocean_tide_fes_2022 + dss.duacs_ssha_karin_2_filtered
ds_eta=dss.eta.compute()
# Out:
# /home1/datahome/mdemol/.miniconda3/envs/histenv2/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv2/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)

# %%
# DRIFTER SEL
time = pd.to_datetime(dss.time.mean().values).round('min')
dt = pd.Timedelta('1d')
dr = xr.open_dataset(os.path.join(drifters_dir, 'L2', 'all_med_variational_1h_v0.nc'))
# Time selection
dr_ = dr.sel(datetime = slice(time-dt, time+dt))
# Under inside SWOT

# %%
figsize=10,10
lon=4
lat=39.3

# %%
fig = plt.figure(figsize=figsize)
fig.patch.set_facecolor('white')#no transparancy in png
ax = fig.add_subplot(111, projection=ccrs.Orthographic(lon, lat))
ds_eta.plot(x='longitude', y='latitude', transform=crs, ax=ax)

# %%
ds_eta.plot(x='longitude', y='latitude')

# %%
def print_swot(pass_, cycle):
    df_ = dfs.where(dfs.pass_number==int(3)).where(dfs.pass_number==int(3)).dropna()
# Out:
# <xarray.Dataset>
# Dimensions:                                  (num_lines: 4161, num_pixels: 519)
# Coordinates:
#     latitude                                 (num_lines, num_pixels) float64 ...
#     longitude                                (num_lines, num_pixels) float64 ...
# Dimensions without coordinates: num_lines, num_pixels
# Data variables: (12/36)
#     ancillary_surface_classification_flag    (num_lines, num_pixels) float32 ...
#     cross_track_distance                     (num_lines, num_pixels) float32 ...
#     cvl_dac                                  (num_lines, num_pixels) float64 ...
#     cvl_distance_to_coast                    (num_lines, num_pixels) float64 ...
#     cvl_flag_val                             (num_lines, num_pixels) float32 ...
#     cvl_ice_conc                             (num_lines, num_pixels) float64 ...
#     ...                                       ...
#     pass_number                              (num_lines) uint16 ...
#     sig0_karin_2                             (num_lines, num_pixels) float32 ...
#     ssh_karin_2_qual                         (num_lines, num_pixels) float64 ...
#     time                                     (num_lines) datetime64[ns] ...
#     time_tai                                 (num_lines) datetime64[ns] ...
#     version                                  (num_lines) |S7 ...
# Attributes:
#     latc:     39.961324
#     lonc:     4.3749
#     phi:      76.80931729750102
