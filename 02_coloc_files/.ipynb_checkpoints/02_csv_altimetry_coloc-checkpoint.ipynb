# %% [markdown]
# ____
# # INTERPOLATE AND ROTATE SWOT DATA ON COLOC POINTS

# %%
import numpy as np
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt

import os
from glob import glob

from cstes import swot_dir, drifters_dir, get_proj, lonlat2xy, zarr_dir
from swot import browse_swot_2km, add_mask_inside_swot, add_grid_metrics, build_swath_polygon
#from diagnosis import drifters_sources

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.geodesic as cgeo
crs = ccrs.PlateCarree()

import cartopy.geodesic as geod
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import pyproj
from pyproj import Geod

from rasterio.transform import Affine

import pynsitu as pyn
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Warning: could not import gsw
# Warning: could not import pytide
# Warning: could not import utide
# Warning: could not import pyTMD

# %% [markdown]
# _______________
# # CHOOSE coloc sources

# %%
drifters_sources = 'all_med_variational_10min_v0.nc'

# Drifters param
dt = '12h'
drifter_preprocess = 'spectral_decomp' # '', 'spectral_decomp', 'low_pass'

if drifter_preprocess == True : drifters_sources = 'spectral_decomp_'+ drifters_sources

colocs_source = f'{dt}_{drifter_preprocess}_{drifters_sources}'.replace('.nc', '.csv')

# Drifters
df = pd.read_csv(os.path.join(zarr_dir,'coloc_files', 'drifters', f'drifterscoloc_'+colocs_source), dtype={'drifter_id':str}, parse_dates=['datetime']).set_index('row_number')

# %% [markdown]
# _________
# # Functions

# %%
ggd_variables = ['cvl_mean_dynamic_topography_cnes_cls_22',
                 'cvl_mean_sea_surface_cnes_22_hybrid',
                 'cvl_ocean_tide_fes_2022',
                 'cvl_ssha_reference',
                 'duacs_ssha_karin_2_calibrated',
                 'duacs_ssha_karin_2_filtered',]


variables =[#'ancillary_surface_classification_flag',
    'cross_track_distance',
    'distance_to_coast',
    'duacs_editing_flag',
    #'duacs_phase_screen',
    #'duacs_phase_screen_orbit',
    #'duacs_phase_screen_static',
    'duacs_relative_vorticity',
    'duacs_speed_meridional',
    'duacs_speed_meridional_abs',
    'duacs_speed_zonal',
    'duacs_speed_zonal_abs',
    'duacs_strain',
    'duacs_xcal',
    'sig0_karin_2',
    'phi',
    'swh_model', 
    'ssh_karin_uncert',
    'pass_number',
    'phi'
]


from swot import interp_dss, rotate
def interp_coloc_one_cycle(dfr_, dsalti, cycle):#, vars_to_rotate=[]):

    # ATTENTION : NEED TO REMOVE VARIABLES FOR WHICH LONGITUDE, LATITUDE ARE NOT COORDS
    dropv = []
    if 'pass_number' in dsalti.keys() : dropv +=['pass_number']
    if 'npts' in dsalti.keys() : dropv +=['npts']
    if 'cutoff' in dsalti.keys() : dropv +=['cutoff']
    
    df_interp = interp_dss(dsalti.drop_vars(dropv), dfr_.longitude.values, dfr_.latitude.values)
    df_out = pd.concat([dfr_.reset_index()[['row_number', 'longitude']].set_index('longitude'), df_interp.set_index('longitude')], axis=1).reset_index().set_index('row_number')
    #for v in vars_to_rotate :
    #    df_out[v[O]], df_out[v[1]] = rotate(df_out[v[O]], df_out[v[1]], df_out(phi))
    return df_out
    
def coloc_swot_2km(dfr, dsalti):
    swath = dsalti.pass_number.values

    DF = []
    for cycle in dfr[dfr.pass_number==swath].cycle_number.unique():
        try : 
            dfr_ = dfr.where((dfr.pass_number==swath)&(dfr.cycle_number==cycle)).dropna()
            dsalti_ = dsalti.sel(cycle_number=cycle)
            DF.append(interp_coloc_one_cycle(dfr_, dsalti_, cycle))
        except : 
            print('no', cycle)
            continue
        #print(cycle)
    df_out = pd.concat(DF)
    if 'npts' in dsalti.keys(): df_out['npts'] = dsalti.npts.values
    if 'cutoff' in dsalti.keys(): df_out['cutoff'] = dsalti.cutoff.values
    return df_out

def coloc_L4(dfr, dsalti):
    lon = df.longitude.values
    lat = df.latitude.values
    t = pd.to_datetime(df.datetime).values
    ds0 = dsalti.interp(longitude=('z', lon), latitude=('z',lat), time= ('z',t))
    df0 = ds0.to_dataframe()
    df0.index.names = ['row_number'] 
    return df0

# %% [markdown]
# ___________
# # Find all L4 files

# %%
alti_files = glob(os.path.join(zarr_dir, 'before_coloc', 'L4_sealevel', '*'))
alti_files
# Out:
# ['/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/L4_sealevel/L4_noswot_regional.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/L4_sealevel/L4_withnadirswot.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/L4_sealevel/L4_noswot_global.nc']

# %%
for f in alti_files : 
    dsalti = xr.open_dataset(f)
    dfout = coloc_L4(df, dsalti)
    dfout.to_csv(os.path.join(zarr_dir, "coloc_files",'alti', 'alticoloc_'+f.split('/')[-1].replace('.nc', '_'+colocs_source)))

# %% [markdown]
# ___________
# # Find all preprocessed swot-2km files

# %%
alti_files = glob(os.path.join(zarr_dir, 'before_coloc', 'preprocessed_swot', 'swot2km', '*', '*'))
alti_files = [f.replace('pass3', 'pass*') for f in alti_files if 'pass3' in f]
alti_files
# Out:
# ['/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/fitting_kernel/pass*_15_swot2km_fitting_kernel.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/fitting_kernel/pass*_13_swot2km_fitting_kernel.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/fitting_kernel/pass*_11_swot2km_fitting_kernel.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/fitting_kernel/pass*_9_swot2km_fitting_kernel.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/fitting_kernel/pass*_7_swot2km_fitting_kernel.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/fitting_kernel/pass*_17_swot2km_fitting_kernel.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/fitting_kernel/pass*_5_swot2km_fitting_kernel.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/general/pass*_swot2km_general.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/gaussian/pass*_15000_swot2km_gaussian.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/gaussian/pass*_35000_swot2km_gaussian.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/gaussian/pass*_30000_swot2km_gaussian.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/gaussian/pass*_55000_swot2km_gaussian.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/gaussian/pass*_50000_swot2km_gaussian.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/gaussian/pass*_5000_swot2km_gaussian.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/gaussian/pass*_40000_swot2km_gaussian.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/gaussian/pass*_45000_swot2km_gaussian.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/gaussian/pass*_20000_swot2km_gaussian.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/gaussian/pass*_10000_swot2km_gaussian.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/gaussian/pass*_25000_swot2km_gaussian.nc',
#  '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot2km/diff_only/pass*_swot2km_diff_only.nc']

# %% [markdown]
# # Interpolate

# %%
for i in range(len(alti_files)) :

    path = alti_files[i].replace('/'.join(alti_files[i].split('/')[6:10]), 'coloc_files/alti').replace('pass*', 'alticoloc').replace('.nc', '_'+colocs_source)
    if os.path.isfile(path) :
        print(f'file already exists : {path}')
        continue
        
    # Alti files
    files = glob(alti_files[i])
    D=[]
    for f in files:
        try : 
            
            dsalti = xr.open_dataset(f).compute()
            if 'phi' in dsalti.variables: dsalti = dsalti.reset_coords(['phi', 'dx', 'dy'])
            D.append(coloc_swot(df, dsalti))
        except :
            assert False, f'pb with {f}'
    pd.concat(D, axis=0).to_csv(path)
    print(path)
# Out:
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_15_swot2km_fitting_kernel_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_13_swot2km_fitting_kernel_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_11_swot2km_fitting_kernel_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_9_swot2km_fitting_kernel_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_7_swot2km_fitting_kernel_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_17_swot2km_fitting_kernel_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_5_swot2km_fitting_kernel_12h_spectral_decomp_all_med_variational_10min_v0.csv
# no 554
# no 568
# /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_swot2km_general_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_15000_swot2km_gaussian_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_35000_swot2km_gaussian_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_30000_swot2km_gaussian_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_55000_swot2km_gaussian_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_50000_swot2km_gaussian_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_5000_swot2km_gaussian_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_40000_swot2km_gaussian_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_45000_swot2km_gaussian_12h_spectral_decomp_all_med_variational_10min_v0.csv
# file already exists : /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_20000_swot2km_gaussian_12h_spectral_decomp_all_med_variational_10min_v0.csv
# no 554
# no 568
# /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_10000_swot2km_gaussian_12h_spectral_decomp_all_med_variational_10min_v0.csv
# no 554
# no 568
# /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_25000_swot2km_gaussian_12h_spectral_decomp_all_med_variational_10min_v0.csv
# no 554
# no 568
# /home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/coloc_files/alti/alticoloc_swot2km_diff_only_12h_spectral_decomp_all_med_variational_10min_v0.csv

# %% [markdown]
# # Find L3-250m

# %%
alti_dir = glob(os.path.join(zarr_dir, 'before_coloc', 'preprocessed_swot', 'swot250m', '*', '*'))
#alti_files = [f.replace('pass3', 'pass*') for f in alti_files if 'pass3' in f]
alti_dir = np.unique(['/'.join(f.split('/')[:-1]) for f in alti_dir])

# %%
if True:
    from dask.distributed import Client
    from dask_jobqueue import PBSCluster
    from dask import config

    config.set({"distributed.comm.timeouts.connect": "200s"})
    cluster = PBSCluster(cores=28, processes=28, walltime="03:00:00")
    # cluster = PBSCluster(cores=20, processes=20, walltime='02:00:00')#8
    w = cluster.scale(jobs=2)
# Out:
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask/config.py:742: FutureWarning: Dask configuration key 'distributed.scheduler.transition-log-length' has been deprecated; please use 'distributed.admin.low-level-log-length' instead
#   warnings.warn(
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask/config.py:742: FutureWarning: Dask configuration key 'distributed.comm.recent-messages-log-length' has been deprecated; please use 'distributed.admin.low-level-log-length' instead
#   warnings.warn(
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask_jobqueue/core.py:237: FutureWarning: extra has been renamed to worker_extra_args. You are still using it (even if only set to []; please also check config files). If you did not set worker_extra_args yet, extra will be respected for now, but it will be removed in a future release. If you already set worker_extra_args, extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask_jobqueue/core.py:255: FutureWarning: job_extra has been renamed to job_extra_directives. You are still using it (even if only set to []; please also check config files). If you did not set job_extra_directives yet, job_extra will be respected for now, but it will be removed in a future release. If you already set job_extra_directives, job_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask_jobqueue/core.py:274: FutureWarning: env_extra has been renamed to job_script_prologue. You are still using it (even if only set to []; please also check config files). If you did not set job_script_prologue yet, env_extra will be respected for now, but it will be removed in a future release. If you already set job_script_prologue, env_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45642 instead
#   warnings.warn(

# %%
cluster.close()

# %%
ddf = from_pandas(df, chunksize=1000)[['longitude', 'latitude','pass_number', 'cycle_number']].persist()

def wrapper_interp_one_cycle(df):
    swath = int(df.reset_index().pass_number.values[0])
    cycle = int(df.reset_index().cycle_number.values[0])
    print(swath, cycle)
    dsalti = xr.open_dataset(os.path.join(dir, f'{int(swath)}_{int(cycle)}.nc'))
    return interp_coloc_one_cycle(df, dsalti, int(cycle))

from dask.dataframe import from_pandas
df_out = ddf.groupby(['pass_number', 'cycle_number']).apply(wrapper_interp_one_cycle).reset_index()
# Out:
# 3 478
# KeyboardInterrupt

# %%
from dask.dataframe import from_pandas

# %%
df_out = from_pandas(df, npartitions=10).groupby(['pass_number', 'cycle_number']).apply(wrapper_interp_one_cycle).reset_index()
# Out:
# Index(['row_number', 'pass_number', 'drifter_id', 'datetime', 'x', 'y',
#        'cruise_id', 'lonc', 'latc', 'longitude', 'latitude', 'velocity_east',
#        'velocity_north', 'velocity', 'acceleration_east', 'acceleration_north',
#        'acceleration', 'X', 'gap_mask', 'gaps', 'sign_acceleration',
#        'HF_velocity_east', 'HF_velocity_north', 'HF_acceleration_east',
#        'HF_acceleration_north', 'LF_velocity_east', 'LF_velocity_north',
#        'LF_acceleration_east', 'LF_acceleration_north',
#        'inertial_velocity_east', 'inertial_velocity_north',
#        'inertial_acceleration_east', 'inertial_acceleration_north',
#        'diurnal_velocity_east', 'diurnal_velocity_north',
#        'diurnal_acceleration_east', 'diurnal_acceleration_north',
#        'semidiurnal_velocity_east', 'semidiurnal_velocity_north',
#        'semidiurnal_acceleration_east', 'semidiurnal_acceleration_north',
#        'inside_left', 'inside_right', 'drifter_type', 'time_to_swot',
#        'cycle_number', 'cycle_date'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot250m/diff_only/1_1.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '6e9f6aef-8527-4ec3-acca-ef6a6fe6855c']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask/dataframe/utils.py:194, in raise_on_meta_error(funcname, udf)
#     193 try:
# --> 194     yield
#     195 except Exception as e:
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask/dataframe/groupby.py:2458, in _GroupBy.apply(self, func, *args, **kwargs)
#    2457     meta_args, meta_kwargs = _extract_meta((args, kwargs), nonempty=True)
# -> 2458     meta = self._meta_nonempty.apply(func, *meta_args, **meta_kwargs)
#    2460 msg = (
#    2461     "`meta` is not specified, inferred from partial data. "
#    2462     "Please provide `meta` if the result is unexpected.\n"
#    (...)
#    2465     "  or:     .apply(func, meta=('x', 'f8'))            for series result"
#    2466 )
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1824, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1823 try:
# -> 1824     result = self._python_apply_general(f, self._selected_obj)
#    1825     if (
#    1826         not isinstance(self.obj, Series)
#    1827         and self._selection is None
#    1828         and self._selected_obj.shape != self._obj_with_exclusions.shape
#    1829     ):
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1885, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1859 """
#    1860 Apply function f in python space
#    1861
#    (...)
#    1883     data after applying f
#    1884 """
# -> 1885 values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1886 if not_indexed_same is None:
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/pandas/core/groupby/ops.py:919, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     918 group_axes = group.axes
# --> 919 res = f(group)
#     920 if not mutated and not _is_indexed_like(res, group_axes, axis):
#
# Cell In[62], line 5, in wrapper_interp_one_cycle(df)
#       4 cycle = int(df.reset_index().cycle_number.values[0])
# ----> 5 dsalti = xr.open_dataset(os.path.join(dir, f'{int(swath)}_{int(cycle)}.nc'))
#       6 return interp_coloc_one_cycle(df, dsalti, int(cycle))
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/api.py:588, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     587 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 588 backend_ds = backend.open_dataset(
#     589     filename_or_obj,
#     590     drop_variables=drop_variables,
#     591     **decoders,
#     592     **kwargs,
#     593 )
#     594 ds = _dataset_from_backend_dataset(
#     595     backend_ds,
#     596     filename_or_obj,
#    (...)
#     606     **kwargs,
#     607 )
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:645, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     644 filename_or_obj = _normalize_path(filename_or_obj)
# --> 645 store = NetCDF4DataStore.open(
#     646     filename_or_obj,
#     647     mode=mode,
#     648     format=format,
#     649     group=group,
#     650     clobber=clobber,
#     651     diskless=diskless,
#     652     persist=persist,
#     653     lock=lock,
#     654     autoclose=autoclose,
#     655 )
#     657 store_entrypoint = StoreBackendEntrypoint()
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:408, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     405 manager = CachingFileManager(
#     406     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     407 )
# --> 408 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:355, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     354 self._mode = mode
# --> 355 self.format = self.ds.data_model
#     356 self._filename = self.ds.filepath()
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:417, in NetCDF4DataStore.ds(self)
#     415 @property
#     416 def ds(self):
# --> 417     return self._acquire()
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:411, in NetCDF4DataStore._acquire(self, needs_lock)
#     410 def _acquire(self, needs_lock=True):
# --> 411     with self._manager.acquire_context(needs_lock) as root:
#     412         ds = _nc4_require_group(root, self._group, self._mode)
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     198 """Context manager for acquiring a file."""
# --> 199 file, cached = self._acquire_with_cache_info(needs_lock)
#     200 try:
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#
# File src/netCDF4/_netCDF4.pyx:2469, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2028, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/datawork-lops-oc/aponte/margot/DATA_MED_COLOC/before_coloc/preprocessed_swot/swot250m/diff_only/1_1.nc'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df_out = from_pandas(df, npartitions=10).groupby(['pass_number', 'cycle_number']).apply(wrapper_interp_one_cycle).reset_index()
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask/dataframe/groupby.py:2458, in _GroupBy.apply(self, func, *args, **kwargs)
#    2456 with raise_on_meta_error(f"groupby.apply({funcname(func)})", udf=True):
#    2457     meta_args, meta_kwargs = _extract_meta((args, kwargs), nonempty=True)
# -> 2458     meta = self._meta_nonempty.apply(func, *meta_args, **meta_kwargs)
#    2460 msg = (
#    2461     "`meta` is not specified, inferred from partial data. "
#    2462     "Please provide `meta` if the result is unexpected.\n"
#    (...)
#    2465     "  or:     .apply(func, meta=('x', 'f8'))            for series result"
#    2466 )
#    2467 warnings.warn(msg, stacklevel=2)
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     135     value = typ()
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#     142     return exc is not value
#
# File ~/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask/dataframe/utils.py:215, in raise_on_meta_error(funcname, udf)
#     206 msg += (
#     207     "Original error is below:\n"
#     208     "------------------------\n"
#    (...)
#     212     "{2}"
#     213 )
#     214 msg = msg.format(f" in `{funcname}`" if funcname else "", repr(e), tb)
# --> 215 raise ValueError(msg) from e
#
# ValueError: Metadata inference failed in `groupby.apply(wrapper_interp_one_cycle)`.
#
# You have supplied a custom function and Dask is unable to
# determine the type of output that that function returns.
#
# To resolve this please provide a meta= keyword.
# The docstring of the Dask function you ran should have more information.
#
# Original error is below:
# ------------------------
# FileNotFoundError(2, 'No such file or directory')
#
# Traceback:
# ---------
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask/dataframe/utils.py", line 194, in raise_on_meta_error
#     yield
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/dask/dataframe/groupby.py", line 2458, in apply
#     meta = self._meta_nonempty.apply(func, *meta_args, **meta_kwargs)
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py", line 1824, in apply
#     result = self._python_apply_general(f, self._selected_obj)
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py", line 1885, in _python_apply_general
#     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/pandas/core/groupby/ops.py", line 919, in apply_groupwise
#     res = f(group)
#   File "/dev/shm/pbs.2642429.datarmor0/ipykernel_44325/1099835563.py", line 5, in wrapper_interp_one_cycle
#     dsalti = xr.open_dataset(os.path.join(dir, f'{int(swath)}_{int(cycle)}.nc'))
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/api.py", line 588, in open_dataset
#     backend_ds = backend.open_dataset(
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py", line 645, in open_dataset
#     store = NetCDF4DataStore.open(
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py", line 408, in open
#     return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py", line 355, in __init__
#     self.format = self.ds.data_model
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py", line 417, in ds
#     return self._acquire()
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py", line 411, in _acquire
#     with self._manager.acquire_context(needs_lock) as root:
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/contextlib.py", line 119, in __enter__
#     return next(self.gen)
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/file_manager.py", line 199, in acquire_context
#     file, cached = self._acquire_with_cache_info(needs_lock)
#   File "/home1/datahome/mdemol/.miniconda3/envs/histenv/lib/python3.9/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info
#     file = self._opener(*self._args, **kwargs)
#   File "src/netCDF4/_netCDF4.pyx", line 2469, in netCDF4._netCDF4.Dataset.__init__
#   File "src/netCDF4/_netCDF4.pyx", line 2028, in netCDF4._netCDF4._ensure_nc_success

# %%
dfr_ = df.where((df.pass_number==3)&(df.cycle_number==500)).dropna()
wrapper_interp_one_cycle(dfr_)
# Out:
# Index(['row_number', 'pass_number', 'drifter_id', 'datetime', 'x', 'y',
#        'cruise_id', 'lonc', 'latc', 'longitude', 'latitude', 'velocity_east',
#        'velocity_north', 'velocity', 'acceleration_east', 'acceleration_north',
#        'acceleration', 'X', 'gap_mask', 'gaps', 'sign_acceleration',
#        'HF_velocity_east', 'HF_velocity_north', 'HF_acceleration_east',
#        'HF_acceleration_north', 'LF_velocity_east', 'LF_velocity_north',
#        'LF_acceleration_east', 'LF_acceleration_north',
#        'inertial_velocity_east', 'inertial_velocity_north',
#        'inertial_acceleration_east', 'inertial_acceleration_north',
#        'diurnal_velocity_east', 'diurnal_velocity_north',
#        'diurnal_acceleration_east', 'diurnal_acceleration_north',
#        'semidiurnal_velocity_east', 'semidiurnal_velocity_north',
#        'semidiurnal_acceleration_east', 'semidiurnal_acceleration_north',
#        'inside_left', 'inside_right', 'drifter_type', 'time_to_swot',
#        'cycle_number', 'cycle_date'],
#       dtype='object')
#             longitude   latitude      etaf       dx_etaf   dy_etaf  \
# row_number
# 53513        5.045020  40.286939  0.057376  3.422019e-07 -0.000001
# 53514        5.045803  40.286533  0.057412  3.516950e-07 -0.000002
# 53515        5.046585  40.286116  0.057503  3.918966e-07 -0.000002
# 53516        5.047365  40.285685  0.057596  4.154305e-07 -0.000002
# 53517        5.048142  40.285242  0.057757  4.555073e-07 -0.000002
# ...               ...        ...       ...           ...       ...
# 57048        4.403015  40.324339  0.005307 -1.239308e-06 -0.000005
# 57049        4.403785  40.323726  0.005523 -1.321102e-06 -0.000005
# 57050        4.404564  40.323132  0.005862 -1.503439e-06 -0.000004
# 57051        4.405359  40.322559  0.005935 -1.468539e-06 -0.000004
# 57052        4.406172  40.322006  0.006045 -1.303938e-06 -0.000004
#
#                 dxx_etaf      dyy_etaf      dxy_etaf      etac   dx_etac  \
# row_number
# 53513      -6.491333e-11 -5.464827e-10 -1.323708e-09  0.064063  0.000008
# 53514       1.189153e-10 -3.884727e-10 -1.350589e-09  0.065118 -0.000009
# 53515      -1.536175e-10 -3.919713e-10 -1.250412e-09  0.064231 -0.000006
# 53516      -4.033814e-10 -3.090622e-10 -9.237426e-10  0.061966 -0.000004
# 53517      -4.102266e-10  1.842134e-11 -9.144585e-10  0.059722 -0.000006
# ...                  ...           ...           ...       ...       ...
# 57048       5.972322e-10  2.104105e-10  1.185727e-09 -0.008635  0.000046
# 57049       4.303572e-10 -7.338493e-10  1.608939e-09  0.001911  0.000066
# 57050       4.647424e-10 -1.888237e-09  1.212528e-09  0.010797  0.000065
# 57051       7.525479e-10 -1.739355e-09  9.364895e-10  0.014638  0.000059
# 57052       1.754502e-09 -1.254930e-09  2.505973e-10  0.023200  0.000037
#
#              dy_etac      dxx_etac      dyy_etac      dxy_etac
# row_number
# 53513       0.000023 -1.660042e-07 -1.497744e-07 -2.220944e-08
# 53514       0.000026 -1.399488e-07 -1.721432e-07 -1.543800e-07
# 53515       0.000026 -1.264405e-07 -1.785506e-07 -1.630884e-07
# 53516       0.000013 -1.168313e-07 -1.747777e-07 -1.130119e-07
# 53517       0.000013 -9.420365e-08 -1.736895e-07 -1.063205e-07
# ...              ...           ...           ...           ...
# 57048      -0.000018  3.131464e-07  2.560355e-07  1.794808e-07
# 57049      -0.000016  1.783067e-07  8.891958e-08  1.358912e-07
# 57050      -0.000008  1.201992e-07 -5.240604e-08  2.000784e-07
# 57051       0.000004  5.679040e-08 -1.103482e-07  1.879191e-07
# 57052       0.000037 -7.460854e-08 -2.266517e-07  1.170137e-07
#
# [3540 rows x 14 columns]
